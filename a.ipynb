# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.48.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.11.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-4.1.0

# %%
import os
import shutil
from pathlib import Path
from sentence_transformers import SentenceTransformer, util

# Load a small, efficient sentence transformer
model = SentenceTransformer('all-MiniLM-L6-v2')

# Define categories and their keywords
categories = {
    "Kicks": ["kick"],
    "Snares": ["snare"],
    "Hats": ["hat", "hihat", "hi-hat"],
    "Claps": ["clap"],
    "Percussion": ["perc", "percussion"],
    "Cymbals": ["cymbal", "ride", "crash"],
    "Drum Loops": ["drum loop", "full drum loop"],
    "Top Loops": ["top loop"],
    "Hat Loops": ["hat loop", "hihat loop", "hi-hat loop"],
    "Kick Loops": ["kick loop"],
    "Percussion Loops": ["perc loop", "percussion loop"],
    "Guitar One-shots": ["guitar"],
    "Piano One-shots": ["piano"],
    "Keys/Synth One-shots": ["keys", "synth"],
    "Bass One-shots": ["bass"],
    "Vocal Chops": ["vocal"],
    "Guitar Loops": ["guitar loop"],
    "Piano Loops": ["piano loop"],
    "Synth Loops": ["synth loop", "keys loop"],
    "Bass Loops": ["bass loop"],
    "Vocal Loops": ["vocal loop"],
    "FX": ["fx", "impact", "riser", "sweep", "drop"],
    "Ambience/Textures": ["ambience", "texture", "vinyl", "noise"]
}

# Precompute category embeddings for better matching
category_embeddings = {cat: model.encode(cat) for cat in categories.keys()}

def classify_sample(name):
    name_lower = name.lower()

    # Priority 1: Keyword matching with loop differentiation
    if "loop" in name_lower:
        for category, keywords in categories.items():
            if "loop" in category.lower():
                if any(keyword in name_lower for keyword in keywords):
                    return category
        return "Melodic Loops"  # Default loop category if none matched

    # Priority 2: One-shot/instrument matching
    for category, keywords in categories.items():
        if "loop" not in category.lower():
            if any(keyword in name_lower for keyword in keywords):
                return category

    # Priority 3: Use embedding similarity
    name_embedding = model.encode(name)
    scores = {cat: util.cos_sim(name_embedding, emb).item() for cat, emb in category_embeddings.items()}
    best_match = max(scores, key=scores.get)

    # Threshold to avoid bad matches
    if scores[best_match] > 0.4:
        return best_match
    else:
        return "Uncategorized"

def sort_samples(input_folder, output_folder):
    input_folder = Path(input_folder)
    output_folder = Path(output_folder)

    for root, dirs, files in os.walk(input_folder):
        
        for file in files:
            if file.lower().endswith(('.wav', '.mp3', '.flac', '.aiff', '.ogg')):
                file_path = Path(root) / file
                category = classify_sample(file)
                target_dir = output_folder / category
                target_dir.mkdir(parents=True, exist_ok=True)

                shutil.copy(file_path, target_dir / file)
                print(f"Copied {file} to {target_dir}")

input_samples_folder = Path("~/Splice/sounds/packs").expanduser()
output_sorted_folder = "."

sort_samples(input_samples_folder, output_sorted_folder)
# Out:
# Copied SPINNIN_drum_top_loop_running_128.wav to Melodic Loops
# Copied OS_VV3_hihat_record.wav to Hats
# Copied OS_VV3_open_hihat_burn.wav to Hats
# Copied OS_VV3_snare_pocket.wav to Snares
# Copied OS_VV3_rim_smoke.wav to Uncategorized
# Copied OS_VV3_kick_kyoto.wav to Kicks
# Copied OS_VV3_70_drum_loop_smokin.wav to Melodic Loops
# Copied OS_VV3_70_vocal_cuts_sunday_Dm.wav to Vocal Chops
# Copied OS_VV3_70_drum_fill_smokin.wav to Drum Loops
# Copied CDS_DEAD_SNARE_ONE_SHOT_SMACK.wav to Snares
# Copied hk_crash_ricebowl.wav to Cymbals
# Copied SNS_SS_90_drum_loop_misfit.wav to Melodic Loops
# Copied bb2_90_break_loop_broken.wav to Melodic Loops
# Copied SO_ST_100_perc_loop_gold_congas.wav to Melodic Loops
# Copied SO_ST_100_drum_loop_gold_roll.wav to Melodic Loops
# Copied CPA_JSD_153_drum_loop_connect.wav to Melodic Loops
# Copied DD_SJD_snare_one_shot_supra_sidestick_medium.wav to Snares
# Copied CO_NE_80_hat_loop_virginia.wav to Melodic Loops
# Copied KSHMR_Snap_07.wav to Uncategorized
# Copied TL_RG_140_Drum_Loop_Classic_UKG.wav to Melodic Loops
# Copied TS_NEON_snare_one_shot_bonham_zumba.wav to Snares
# Copied TS_NEON_snare_one_shot_pearly_pizzica.wav to Snares
# Copied DKP_bass_808_rekt_E.wav to Bass One-shots
# Copied KSHMR_101_hihat_loop_creative_rattle.wav to Melodic Loops
# Copied KSHMR_128_top_loop_classic.wav to Melodic Loops
# Copied KSHMR_ride_acoustic_ping.wav to Cymbals
# Copied OLIVER_fx_woo.wav to FX
# Copied OLIVER_retro_drum_loop_simple_classic_110.wav to Melodic Loops
# Copied DECAP_DTKX_808_midrange_smooth_C.wav to Uncategorized
# Copied jh2_snare_rim_stick.wav to Snares
# Copied PJ_RS_74_kit_loop_Desire_Hat_Tom_Shake_Percussion_Cmin.wav to Melodic Loops
# Copied Jazz_Ride.wav to Cymbals
# Copied JAZZFEEZY_JSK_Tom_Loop_4Bar_67bpm.wav to Melodic Loops
# Copied OSS_Drums1_70_drums_groove_break_loop_bossa_rider.wav to Melodic Loops
# Copied OS_LM_synth_bass_reese_saws_C.wav to Keys/Synth One-shots
# Copied DD_Folk_Crash_One_Shot_medium.wav to Cymbals
# Copied TS_IR_hats_15_warm_tight.wav to Hats
# Copied BB3_fx_hit_knockout.wav to FX
# Copied 91V_BRC_85_perc_loop_bathroom_jam.wav to Melodic Loops
# Copied STCR2_UKG_132_Drum_Loop_Madness.wav to Melodic Loops
# Copied STCR2_UKG_134_Drum_Loop_Mashed.wav to Melodic Loops
# Copied STCR2_UKG_128_Toploop_Zones.wav to Melodic Loops
# Copied STCR2_UKG_128_Vocal_Hook_Want_Wonderland_WET_Cm.wav to Vocal Chops
# Copied TS_DD_VOL1_kick_round.wav to Kicks
# Copied DSC_MPL_crash_lo_one_shot_soft_dry.wav to Cymbals
# Copied TS_AMD_90_drum_fill_closed_doors.wav to Drum Loops
# Copied TS_AMD_hats_warm_semi_open.wav to Hats
# Copied TS_AMD_hats_warm_open_close.wav to Hats
# Copied ORBIT_FX_Funk_Sparkle.wav to FX
# Copied TS_VHH_snare_high_punch.wav to Snares
# Copied OS_CASH_808_lit_C.wav to Uncategorized
# Copied cd_hat_clankycl.wav to Hats
# Copied 91V_JVR_96_perc_loop_closer_claps_clean.wav to Melodic Loops
# Copied MDT_128_top_loop_deep_house.wav to Melodic Loops
# Copied OSS_TL_96_perc_shakers_bongos_loop_dynamic.wav to Melodic Loops
# Copied OSS_TL_98_drum_loop_hats_lightly_seared.wav to Melodic Loops
# Copied OS_MN_808_udon_C.wav to Uncategorized
# Copied PAT_LOK_drum_loop_hiphopclassic_dilla90s_98.wav to Melodic Loops
# Copied RT_Jazz_Drums_Jazz_Bossa_Sticks_140_Loop_1_Drums_Andreas_Klein_140_loop.wav to Melodic Loops
# Copied NIC_FANCIULLI_124_percussion_loop_tom_noise_wet.wav to Melodic Loops
# Copied OpenHat01.wav to Hats
# Copied SS_FA_120_top_loop_are_you_heaven.wav to Melodic Loops
# Copied SS_FA_120_top_loop_hihat_movement.wav to Melodic Loops
# Copied JAFUNK_110_fx_martian_downlifter_short.wav to FX
# Copied JAFUNK_110_fx_disco_tom_high.wav to FX
# Copied DSC_TPQ_cymbal_crash_soft_dry.wav to Cymbals
# Copied DSC_TPQ_100_drum_loop_dance_fat.wav to Melodic Loops
# Copied DS_LENNO_120_drum_fill_never_fails.wav to Drum Loops
# Copied DS_LENNO_fx_laser_dive.wav to FX
# Copied DS_LENNO_fx_riser_clean.wav to FX
# Copied DS_LENNO_120_drum_hat_moving.wav to Hats
# Copied TVD_rim_tape_vinyl_nice.wav to Ambience/Textures
# Copied STATIK_hihat_loud_alley.wav to Hats
# Copied DD_NEO_77_drums_loop_soul_groove_Hats.wav to Melodic Loops
# Copied OS_RNB_C_Scarlet_Reese_Bass_2.wav to Bass One-shots
# Copied OS_LFC_75_drum_loop_punch.wav to Melodic Loops
# Copied BULLYFINGER_hi_hat_open_one_shot_bliss_darkmatter.wav to Hats
# Copied PL_SS_Click_FX_One_Shot_Reverb.wav to FX
# Copied PL_SS_Knock_FX_One_Shot_Reverb.wav to FX
# Copied PL_SS_Snare_One_Shot_Unfit.wav to Snares
# Copied ESM_Iconic_Escape_Loop_Hip_Hop_Drum_Swing_Old_School_Boom_Bap_Underground_94_Bpm.wav to Melodic Loops
# Copied ESM_Iconic_Eden_Loop_Hip_Hop_Drum_Swing_Old_School_Boom_Bap_Underground_84_Bpm.wav to Melodic Loops
# Copied YNG_snare_powerful_808.wav to Snares
# Copied OLIVER_90_drums_sp12_boom_bap_full.wav to Drum Loops
# Copied BRLY_ALVE_kick_accident.wav to Kicks
# Copied BRLY_ALVE_kick_swipe.wav to Kicks
# Copied BRLY_ALVE_kick_monster.wav to Kicks
# Copied TS_VV_90_hats_doubling.wav to Hats
# Copied TS_WW_100_drum_loop_confident_shaker.wav to Melodic Loops
# Copied X10_OVU_93_drum_loop_opinions.wav to Melodic Loops
# Copied dhh_kick_yella.wav to Kicks
# Copied SO_JC_80_drum_loop_acoustic_tiverton.wav to Melodic Loops
# Copied T_TSMK5_125_top_loop_suga.wav to Melodic Loops
# Copied NOIZU_125_shaker_loop_tight_02.wav to Melodic Loops
# Copied FL_RSC_Kit03_Drum_Loop_Tambourine_104.wav to Melodic Loops
# Copied NH_BL_kick_live_normie.wav to Kicks
# Copied NH_BL_hat_open_live_openlong.wav to Hats
# Copied NH_BL_hat_closed_live_topsoft.wav to Hats
# Copied BFTF_-_Ride_Tape_Funk_02.wav to Cymbals
# Copied BFTF_-_100_-_Rides_Loop.wav to Melodic Loops
# Copied OS_MLW_hihat_light.wav to Hats
# Copied OS_MLW_sfx_gentle_rain.wav to FX
# Copied SLS_CSP_hihat_meaty_closed_bright.wav to Hats
# Copied SLS_CSP_kick_ferris.wav to Kicks
# Copied SLS_CSP_hihat_doubletap.wav to Hats
# Copied SLS_CSP_hihat_loose_change.wav to Hats
# Copied SLS_CSP_hihat_grit_open.wav to Hats
# Copied SLS_CSP_hihat_grit_closed.wav to Hats
# Copied SLS_CSP_kick_father.wav to Kicks
# Copied SLS_CSP_kick_intro.wav to Kicks
# Copied SLS_CSP_snare_acoustic_rim_above.wav to Snares
# Copied SLS_CSP_snare_acoustic_anotha_one.wav to Snares
# Copied SLS_CSP_65_electric_piano_runs_ambient_delay_soul_hedges_Bmin.wav to Piano One-shots
# Copied SLS_CSP_86_drum_kit_rnb_mice.wav to Percussion
# Copied SLS_CSP_83_drum_kit_rnb_wrestle.wav to Percussion
# Copied SLS_CSP_84_drum_kit_rnb_setup.wav to Drum Loops
# Copied SLS_CSP_77_drum_kit_rnb_sonny.wav to Percussion
# Copied SPS_95_drum_loop_dum_dum.wav to Melodic Loops
# Copied OS_FC_snare_thai.wav to Snares
# Copied SCTHC_Drum_Loop_12_Top_123.wav to Melodic Loops
# Copied DSC_TPF_drum_loop_114_mustang.wav to Melodic Loops
# Copied AT_Birdhouse_HiHat_Closed_One_Shot_Grill.wav to Hats
# Copied RKU_ARSA_97_drum_loop_full_unsaid.wav to Melodic Loops
# Copied TS_VV_snare_cross_stick_roomy.wav to Snares
# Copied RKU_UME_100_drum_loop_full_slowburn_first.wav to Melodic Loops
# Copied DS_DPW_120_drum_fill_beat.wav to Drum Loops
# Copied DS_DPW_120_drum_fill_quick_shuffle.wav to Drum Loops
# Copied OLIVER_retro_drum_loop_perfect_clean_disco_100.wav to Melodic Loops
# Copied OS_OG_808_monsters_C.wav to Uncategorized
# Copied SLS_CS_rim_clean.wav to Uncategorized
# Copied OS_FIRE_808_juicy_C.wav to Uncategorized
# Copied CO_CD_75_shaker_loop_driftwood.wav to Melodic Loops
# Copied SO_NT_100_perc_loop_gambia.wav to Melodic Loops
# Copied TS_NEON_113_drum_loop_grooves_nyc_tight_kit_billie_jean_clean.wav to Melodic Loops
# Copied OS_VS_85_drum_fill_resampled_rude.wav to Percussion
# Copied dhdk_clhat_live.wav to Hats
# Copied dhdk_perc_white.wav to Percussion
# Copied dhdk_snare_funk.wav to Snares
# Copied KMRBI_RHS4_108_drum_loop_taste.wav to Melodic Loops
# Copied JJP_60SS_kick_deep_waters.wav to Kicks
# Copied KMRBI_RHXS_snare_one_shot_crisp.wav to Snares
# Copied OSS_SS2_80_drum_top_loop_sidestick_dry_open_hi_hat.wav to Melodic Loops
# Copied lkh_90_drum_loop_brook_full.wav to Melodic Loops
# Copied SO_LF_808_synth_note_quien_me_para_C.wav to Keys/Synth One-shots
# Copied rss_80_vinyl_cut_walkaway_C#min.wav to Ambience/Textures
# Copied rss_90_drum_loop_brokin_full.wav to Melodic Loops
# Copied DD_SAM_98_drums_loop_funk_congas_loop2.wav to Melodic Loops
# Copied dhh2_drum_loop_cool_full_90.wav to Melodic Loops
# Copied adt_85_drum_loop_rattlebreak.wav to Melodic Loops
# Copied SO_SL2_tambourine_wet.wav to Percussion
# Copied SO_SL2_90_shaker_calumethigh.wav to Uncategorized
# Copied OS_SS_hihat_fresh.wav to Hats
# Copied OS_SS_snare_tilt.wav to Snares
# Copied OS_SS_90_drum_loop_swagger.wav to Melodic Loops
# Copied MARS_VINYLDRUMS_Snare_Clean_Hard.wav to Snares
# Copied MARS_VINYLDRUMS_Snare_Tube_Tite.wav to Snares
# Copied TS_PAUL_MABURY_cymbal_one_shot_22_ride_nat_m1.wav to Cymbals
# Copied DSC_VNG3_110_drum_fill_classic_dry.wav to Drum Loops
# Copied SS_TCPT2_crash_reverse_one_shot_kiroku.wav to Cymbals
# Copied TS_VD_kick_60s_slinger_soft.wav to Kicks
# Copied MALAY_drum_loop_saucy_toms_140_E.wav to Melodic Loops
# Copied SC_YTS_120_perc_bongo_classic_dynamic.wav to Percussion
# Copied T_TSCR2_kick_oneshot_afro.wav to Kicks
# Copied DSC_RST_110_drum_loop_pinball_dry.wav to Melodic Loops
# Copied ah_kick_gust.wav to Kicks
# Copied OS_VC_hihat_light.wav to Hats
# Copied TL_AS_One_Shot_Shaker_Vibes.wav to Bass One-shots
# Copied DECAP_kick_perfect_thick_warm.wav to Kicks
# Copied DECAP_87_drum_loop_so_warm_boom_bap_rap_hard_knock.wav to Melodic Loops
# Copied RKU_ASU_126_vocal_chops_loop_motion_wet_Cmin.wav to Melodic Loops
# Copied RKU_ASU_126_top_loop_middle.wav to Melodic Loops
# Copied SO_PD2_90_drums_perc_lilac.wav to Percussion
# Copied SOUTHSIDExPVLACE_808_dread_C.wav to Uncategorized
# Copied PMMDV3_Drum_Fill_03_140BPM.wav to Drum Loops
# Copied DS_VOLAC_percussion_tom_one_shot_human_F#.wav to Percussion
# Copied PE_80_Loop_04_Shaker.wav to Melodic Loops
# Copied SDT_TSS_100_drums_acoustic_kit_w_ride_groove.wav to Cymbals
# Copied OS_SW3_kick_soft.wav to Kicks
# Copied PL_TC_92_Hat_and_Snare_Loop_Vasco.wav to Melodic Loops
# Copied JAFUNK_snare_acoustic_tight.wav to Snares
# Copied OS_UKV_hihat_shine.wav to Hats
# Copied VHB_88_Drum_Loop_Jazzy2.wav to Melodic Loops
# Copied SO_SW2_70_top_loop_blue_skies.wav to Melodic Loops
# Copied SO_SW2_105_drum_loop_simple_sol.wav to Melodic Loops
# Copied OS_AD_kick_smooth.wav to Kicks
# Copied OS_AD_rim_bridge.wav to Uncategorized
# Copied OS_AD_perc_click_reverb.wav to Percussion
# Copied OS_AD_95_piano_chords_hieroglyphics_Am.wav to Piano One-shots
# Copied MURDA_808_samurai_C.wav to Uncategorized
# Copied PL_TS_Kick_One_Shot_Loyalty.wav to Kicks
# Copied PL_TS_90_Full_Drum_Loop_Mentor.wav to Melodic Loops
# Copied DSC_NGL_clap_one_shot_lays.wav to Claps
# Copied DSC_NGL_snare_one_shot_magic.wav to Snares
# Copied DSC_NGL_kick_one_shot_real.wav to Kicks
# Copied DSC_NGL_kick_one_shot_west.wav to Kicks
# Copied DSC_NGL_112_drum_loop_solid.wav to Melodic Loops
# Copied DSC_NGL_120_drum_loop_live.wav to Melodic Loops

# %%
classify_sample("/Users/martinaviles/Splice/sounds/packs/Modern Folk/DrumDrops_Modern_Folk/One_Shots/Crash/DD_Folk_Crash_One_Shot_medium.wav")
# Out:
# 'Cymbals'
