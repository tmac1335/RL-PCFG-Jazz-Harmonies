# %%
import pandas as pd 
from Chord import Chord
from Rule import Rule
from collections import defaultdict
import pitchtypes as pt
from probabilistic_model import ProbabilisticModel

# %%
p_model = ProbabilisticModel()

# %%
data = pd.read_json('../eda/JazzHarmonyTreebank/treebank.json')
trees_data = data[data['trees'].notna()]['trees']
ccts = [x[0]['complete_constituent_tree'] for x in list(trees_data)]

# %%
p_model.fit(ccts)

# %%
def parse_subtree(subtree):
    if isinstance(subtree, dict):
        label = Chord(subtree['label'])
        child_intervals = [str(label.distance_to(Chord(x['label']))) for x in subtree['children']]
        child_qualities = [Chord(x['label']).quality for x in subtree['children']]
        rule = Rule(label.quality, child_intervals, child_qualities)
        
        return rule

# %%
def make_hashable(d):
    def convert(value):
        if isinstance(value, dict):
            return tuple(sorted((k, convert(v)) for k, v in value.items()))
        elif isinstance(value, list):
            return tuple(convert(v) for v in value)
        else:
            return value

    return tuple(sorted((k, convert(v)) for k, v in d.items()))

# %%
count_dict = defaultdict(int)
lhs_count_dict = defaultdict(int)

def parse_leftmost(tree):
    output = []
    steps = []
    stack = [tree]
    parsed_so_far = []

    while stack:
        current = stack.pop(0)
        rule = parse_subtree(current)
        rule_key = rule.make_hashable()
        count_dict[rule_key] += 1
        lhs_count_dict[rule.lhs()] += 1

        steps.append({
            'current': current['label'],
            'parsed_before': parsed_so_far.copy()
        })

        if current.get('children'):
            stack = current['children'] + stack
        else:
            output.append(current['label'])

        parsed_so_far.append(current['label'])

    return steps, count_dict, lhs_count_dict

# %%
for cct in ccts:
    steps, count_dict, lhs_count_dict = parse_leftmost(cct)

# %%
sorted_dict = dict(sorted(count_dict.items(), key=lambda x: x[1], reverse=False))

# %%
lhs_count_dict = dict(sorted(lhs_count_dict.items(), key=lambda x: x[1], reverse=False))
lhs_count_dict
# Out:
# {'sus': 47, 'unknown': 321, 'minor': 2125, 'major': 5455}

# %%
def compute_conditional_probs(count_dict, lhs_count_dict):
    prob_dict = {}
    for rule, count in count_dict.items():
        lhs = rule[2][1]
        if lhs_count_dict[lhs] == 0:
            print(lhs)
        prob_dict[rule] = count / lhs_count_dict[lhs]
    return prob_dict

# %%
def get_rule_probability(node, prob_dict):
    subtree = parse_subtree(node)
    rule_key = subtree.make_hashable()
    return prob_dict.get(rule_key, 0)

# %%
def compute_tree_probability(tree, prob_dict):
    if not tree.get('children'):
        return 1.0  

    prob = get_rule_probability(tree, prob_dict)

    for child in tree['children']:
        prob *= compute_tree_probability(child, prob_dict)

    return prob

# %%
for cct in ccts:
    steps, count_dict, lhs_count_dict = parse_leftmost(cct)
    prob_dict = compute_conditional_probs(count_dict, lhs_count_dict)

# %%
compute_tree_probability(ccts[3], expanded_prob_dict)
# Out:
# 1.8069074877778802e-11

# %%
prob_dict = p_model.prob_dict

# %%
prob_dict
# Out:
# {(('child_intervals', ('0', '0')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.4410143329658214,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0033076074972436605,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.14285714285714285,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.09523809523809523,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.3263506063947078,
#  (('child_intervals', ('1', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.07003089598352215,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.25060075523515274,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.1826295914864401,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.0624785444558874,
#  (('child_intervals', ('5', '0')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.006615214994487321,
#  (('child_intervals', ('5', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.002205071664829107,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.29694473051836595,
#  (('child_intervals', ('1', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.05181918412348401,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.03364229316855476,
#  (('child_intervals', ('8', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('3', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.006865774116031583,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.013731548232063165,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.05733186328555678,
#  (('child_intervals', ('9', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.005149330587023687,
#  (('child_intervals', ('5', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.013044970820460007,
#  (('child_intervals', ('9', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.003089598352214212,
#  (('child_intervals', ('5', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.004119464469618949,
#  (('child_intervals', ('4', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.004119464469618949,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.007717750826901874,
#  (('child_intervals', ('1', '0')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.014332965821389196,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.0017164435290078957,
#  (('child_intervals', ('3', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.007717750826901874,
#  (('child_intervals', ('1', '0')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.1206896551724138,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.0027463096464126332,
#  (('child_intervals', ('1', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.004119464469618949,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.002403020940611054,
#  (('child_intervals', ('2', '0')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0033076074972436605,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.0020597322348094747,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.2857142857142857,
#  (('child_intervals', ('2', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.002403020940611054,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.0054926192928252664,
#  (('child_intervals', ('4', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.005149330587023687,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.025358324145534728,
#  (('child_intervals', ('5', '0')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('6', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.0020597322348094747,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.0006865774116031583,
#  (('child_intervals', ('4', '0')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.009922822491730982,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.002205071664829107,
#  (('child_intervals', ('1', '0')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.008820286659316428,
#  (('child_intervals', ('4', '0')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('6', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.002403020940611054,
#  (('child_intervals', ('1', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.0013731548232063166,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.0006865774116031583,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.0006865774116031583,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.007717750826901874,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.0037761757638173706,
#  (('child_intervals', ('4', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('6', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.0006865774116031583,
#  (('child_intervals', ('11', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('11', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.0006865774116031583,
#  (('child_intervals', ('6', '0')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.002205071664829107,
#  (('child_intervals', ('1', '0')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.09523809523809523,
#  (('child_intervals', ('3', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.0017164435290078957,
#  (('child_intervals', ('11', '0')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('8', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('9', '0')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.002205071664829107,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.09523809523809523,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.09523809523809523,
#  (('child_intervals', ('11', '0')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.015435501653803748,
#  (('child_intervals', ('8', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.006865774116031583,
#  (('child_intervals', ('9', '0')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.034482758620689655,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.1206896551724138,
#  (('child_intervals', ('3', '0')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.08620689655172414,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.034482758620689655,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.1896551724137931,
#  (('child_intervals', ('8', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.0017164435290078957,
#  (('child_intervals', ('3', '0')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('5', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.0010298661174047373,
#  (('child_intervals', ('5', '0')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.034482758620689655,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('11', '0')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.0006865774116031583,
#  (('child_intervals', ('4', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('10', '0')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.1206896551724138,
#  (('child_intervals', ('11', '0')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.034482758620689655,
#  (('child_intervals', ('1', '0')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.13793103448275862,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.05172413793103448,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('7', '0')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('6', '0')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '0')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '1')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '2')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '3')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '4')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '5')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '6')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '7')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '8')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '9')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('0', '10')),
#   ('child_qualities', ('minor', 'sus')),
# ...
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '5')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '6')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '7')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('sus', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('sus', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('unknown', 'major')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('unknown', 'minor')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('unknown', 'sus')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '8')),
#   ('child_qualities', ('unknown', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('major', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('major', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('major', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('major', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('minor', 'major')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('minor', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('minor', 'sus')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('minor', 'unknown')),
#   ('parent_quality', 'unknown')): 0.017241379310344827,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'major')): 0.00034328870580157915,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('sus', 'major')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'minor')): 0.0011025358324145535,
#  (('child_intervals', ('2', '9')),
#   ('child_qualities', ('sus', 'minor')),
#   ('parent_quality', 'sus')): 0.047619047619047616,
#  ...}

# %%
from itertools import product

def expand_prob_dict(prob_dict, default_prob=1e-6):
    INTERVAL_VOCAB = list(str(i) for i in range(12))
    QUALITY_VOCAB = ['major', 'minor', 'sus', 'unknown']

    all_child_intervals = list(product(INTERVAL_VOCAB, repeat=2))
    all_child_qualities = list(product(QUALITY_VOCAB, repeat=2))
    all_parent_qualities = QUALITY_VOCAB

    count_added = 0

    for interval_combo, quality_combo, parent_quality in product(all_child_intervals, all_child_qualities, all_parent_qualities):
        if parent_quality not in quality_combo:
            continue  # skip if parent quality not present in children

        key = Rule(parent_quality, interval_combo, quality_combo).make_hashable()

        if key not in prob_dict:
            prob_dict[key] = default_prob
            count_added += 1

    print(f"Added {count_added} new rules to prob_dict.")
    return prob_dict

# %%
len(prob_dict)
# Out:
# 9216

# %%
Rule(
    'major',
    ['0', '4'],
    ['major', 'minor']
).make_hashable()
# Out:
# (('child_intervals', ('0', '4')),
#  ('child_qualities', ('major', 'minor')),
#  ('parent_quality', 'major'))

# %%
INTERVAL_VOCAB = [str(i) for i in range(12)]
QUALITY_VOCAB = ['major', 'minor', 'sus', 'unknown']

missing = []

for parent_quality in QUALITY_VOCAB:
    for int1 in INTERVAL_VOCAB:
        for q1 in QUALITY_VOCAB:
            for int2 in INTERVAL_VOCAB:
                for q2 in QUALITY_VOCAB:
                    key = Rule(parent_quality, [int1, int2], [q1, q2]).make_hashable()
                    if key not in prob_dict:
                        missing.append(key)

print(f"Total missing combinations: {len(missing)}")
for m in missing[:10]:  # just show a few
    print(m)

# %%
prob_dict = expand_prob_dict(prob_dict,default_prob=1e-6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 prob_dict = expand_prob_dict(prob_dict,default_prob=1e-6)
#
# NameError: name 'expand_prob_dict' is not defined

# %% [markdown]
# # RL Model

# %%
rules = [Rule.unhash(i) for i in prob_dict.keys()]

# %%
class TreeNode:
    def __init__(self, chord):
        self.chord = chord
        self.left = None           # child node
        self.right = None          # child node
        self.parent = None         # to be filled in later

    def is_leaf(self):
        return self.left is None and self.right is None

    def __repr__(self):
        return f"TreeNode(label={self.chord.label})"


def create_parent_node(left, right, parent, parent_quality):
    parent = TreeNode(Chord(f"{parent.chord.label}"))
    parent.left = left
    parent.right = right
    left.parent = parent
    right.parent = parent

    return parent

def get_top_level_nodes(nodes):
    """
    Given a list of TreeNodes (leaves and partial trees), 
    return the current top-level (root) nodes that are not children of any other node.
    """
    return [node for node in nodes if node.parent is None]

# %%
def get_possible_intervals(chord1,chord2):

    intervals = []
    intervals.append([str(chord1.distance_to(chord1)), str(chord1.distance_to(chord2))])
    intervals.append([str(chord1.distance_from(chord2)), str(chord2.distance_to(chord2))])

    return intervals

# %%
def get_qualities(chord1,chord2):
    return [chord1.quality, chord2.quality]

# %%
def get_possible_rhs_from_str(chord1,chord2):
    return [(get_possible_intervals(chord1, chord2)[0], get_qualities(chord1, chord2)), (get_possible_intervals(chord1, chord2)[1], get_qualities(chord1, chord2)),]

# %%
def get_applicable_rules(rhs_list, rules):
    applicable_rules = []
    for rule in rules:
        for rhs in rhs_list:
            if rule.rhs() == rhs:
                applicable_rules.append(rule)
    return applicable_rules

# %%
import torch
import torch.nn as nn

class DQN(nn.Module):
    def __init__(self, history_dim, action_dim, hidden_dim=128):
        super(DQN, self).__init__()

        self.history_encoder = nn.Sequential(
            nn.Linear(history_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )

        self.action_encoder = nn.Sequential(
            nn.Linear(action_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )

        self.scorer = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)  # Output one Q-value
        )

    def forward(self, history_vec, actions_vecs):
        """
        Args:
            history_vec: Tensor (batch_size, history_dim)
            actions_vecs: Tensor (batch_size, num_actions, action_dim)

        Returns:
            q_values: Tensor (batch_size, num_actions)
        """
        batch_size, num_actions, action_dim = actions_vecs.shape

        # Encode the history once
        history_encoded = self.history_encoder(history_vec)  # (batch_size, hidden_dim)

        # Flatten actions and encode them
        actions_flat = actions_vecs.view(-1, action_dim)  # (batch_size * num_actions, action_dim)
        actions_encoded = self.action_encoder(actions_flat)  # (batch_size * num_actions, hidden_dim)
        actions_encoded = actions_encoded.view(batch_size, num_actions, -1)  # (batch_size, num_actions, hidden_dim)

        # Repeat history for each action
        history_repeated = history_encoded.unsqueeze(1).repeat(1, num_actions, 1)  # (batch_size, num_actions, hidden_dim)

        # Concatenate encoded history and actions
        concat = torch.cat([history_repeated, actions_encoded], dim=-1)  # (batch_size, num_actions, hidden_dim*2)

        # Score each (history, action) pair
        q_values = self.scorer(concat).squeeze(-1)  # (batch_size, num_actions)

        return q_values

# %%
import random
import numpy as np

class Environment:

    MAX_RULES = 10
    MAX_ACTIONS = 10
    MAX_CHORDS = 10

    def __init__(self, chord_sequence):
        self.initial_sequence = chord_sequence
        self.current_state = chord_sequence.copy()
        self.current_nodes = [TreeNode(Chord(chord)) for chord in chord_sequence]
        self.actions = self.get_actions()
        self.applied_rules = []

    # Each index of rhs are a list of applicable rules to currentstate and currentstate + 1
    def get_actions(self):
        rhs_list = []

        for i in range(len(self.current_state) - 1):
            chord1 = Chord(self.current_state[i])
            chord2 = Chord(self.current_state[i + 1])
            possible_rhs = get_possible_rhs_from_str(chord1, chord2)
            rhs_list.append(get_applicable_rules(possible_rhs, rules))


        return rhs_list

    def build_action_index_map(self):

        index_map = []
        for i, rule_list in enumerate(self.get_actions()):
            for j, _ in enumerate(rule_list):
                index_map.append((i, j))
        return index_map

    def apply_rule_index(self,rule_index_i,rule_index_j):
        rule = self.actions[rule_index_i][rule_index_j]
        node1 = self.current_nodes[rule_index_i]
        node2 = self.current_nodes[rule_index_i + 1]
        nodes = [node1,node2]
        parent_root_index = rule.child_intervals.index('0') 
        parent = create_parent_node(node1, node2, nodes[parent_root_index], rule.lhs())
        self.current_nodes[rule_index_i] = parent
        self.current_nodes.pop(rule_index_i + 1)
        self.applied_rules.append(rule)
        self.current_nodes = get_top_level_nodes(self.current_nodes)
        self.current_state = [node.chord.label for node in self.current_nodes]
        self.actions = self.get_actions()

    def apply_rule(self, rule, node1, node2):
        nodes = [node1,node2]
        parent_root_index = rule.child_intervals.index('0') 
        parent = create_parent_node(node1, node2, nodes[parent_root_index], rule.lhs())

        self.current_nodes.append(parent)
        self.applied_rules.append(rule)

        self.current_nodes = get_top_level_nodes(self.current_nodes)
        self.current_state = [node.chord.label for node in self.current_nodes]
        self.actions = self.get_actions()

    def get_state_tensor2(self):
        QUALITY_VOCAB = ['major', 'minor', 'sus', 'unknown']
        INTERVAL_VOCAB = [str(i) for i in range(0,12)]

        def one_hot_encode(value, vocab):
            vec = [0] * len(vocab)
            idx = vocab.index(value if value in vocab else vocab.index('Other'))
            vec[idx] = 1
            return vec

        def encode_rule(rule):
            parent_vec = one_hot_encode(rule.parent_quality, QUALITY_VOCAB)

            interval1_vec = one_hot_encode(rule.child_intervals[0], INTERVAL_VOCAB)
            quality1_vec = one_hot_encode(rule.child_qualities[0], QUALITY_VOCAB)

            interval2_vec = one_hot_encode(rule.child_intervals[1], INTERVAL_VOCAB)
            quality2_vec = one_hot_encode(rule.child_qualities[1], QUALITY_VOCAB)

            return parent_vec + interval1_vec + quality1_vec + interval2_vec + quality2_vec

        chord_vector = []
        for chord in self.current_state[:self.MAX_CHORDS]:
            chord_vector.append(Chord.encode_chord(chord))

        # Pad if needed
        while len(chord_vector) < self.MAX_CHORDS:
            chord_vector.append([0] * len(chord_vector[0]))

        flat_chord_vector = [val for chord in chord_vector for val in chord]
        # chord_tensor = torch.tensor(flat_chord_vector, dtype=torch.float32).unsqueeze(0)

        actions = self.get_actions()
        action_vector = []

        count = 0
        for i in range(len(actions)):
            for j in range(len(actions[i])):
                if count >= self.MAX_ACTIONS:
                    break
                action_vector.append(encode_rule(actions[i][j]))
                count += 1
            if count >= self.MAX_ACTIONS:
                break
        
        flat_action_vector = [val for action in action_vector for val in action]

        return torch.tensor(flat_chord_vector + flat_action_vector, dtype=torch.float32)
        # rule_dim = len(action_vector[0]) if action_vector else 0
        # while len(action_vector) < self.MAX_ACTIONS:
        #     action_vector.append([0] * rule_dim)

        # actions_tensor = torch.tensor(action_vector, dtype=torch.float32).unsqueeze(0)
        # return chord_tensor, actions_tensor


    def get_state_tensor(self):
        QUALITY_VOCAB = ['major', 'minor', 'sus', 'unknown']
        INTERVAL_VOCAB = [str(i) for i in range(0,12)]

        def one_hot_encode(value, vocab):
            vec = [0] * len(vocab)
            idx = vocab.index(value if value in vocab else vocab.index('Other'))
            vec[idx] = 1
            return vec

        def encode_rule(rule):
            parent_vec = one_hot_encode(rule.parent_quality, QUALITY_VOCAB)

            interval1_vec = one_hot_encode(rule.child_intervals[0], INTERVAL_VOCAB)
            quality1_vec = one_hot_encode(rule.child_qualities[0], QUALITY_VOCAB)

            interval2_vec = one_hot_encode(rule.child_intervals[1], INTERVAL_VOCAB)
            quality2_vec = one_hot_encode(rule.child_qualities[1], QUALITY_VOCAB)

            return parent_vec + interval1_vec + quality1_vec + interval2_vec + quality2_vec

        chord_vector = []
        for chord in self.current_state[:self.MAX_CHORDS]:
            chord_vector.append(Chord.encode_chord(chord))

        # Pad if needed
        while len(chord_vector) < self.MAX_CHORDS:
            chord_vector.append([0] * len(chord_vector[0]))

        flat_chord_vector = [val for chord in chord_vector for val in chord]
        chord_tensor = torch.tensor(flat_chord_vector, dtype=torch.float32).unsqueeze(0)

        actions = self.get_actions()
        action_vector = []

        count = 0
        for i in range(len(actions)):
            for j in range(len(actions[i])):
                if count >= self.MAX_ACTIONS:
                    break
                action_vector.append(encode_rule(actions[i][j]))
                count += 1
            if count >= self.MAX_ACTIONS:
                break

        rule_dim = len(action_vector[0]) if action_vector else 0
        while len(action_vector) < self.MAX_ACTIONS:
            action_vector.append([0] * rule_dim)

        actions_tensor = torch.tensor(action_vector, dtype=torch.float32).unsqueeze(0)
        return chord_tensor, actions_tensor

    def step(self, epsilon=0.3):
        chord_tensor, actions_tensor = self.get_state_tensor()
        results = self.model.forward(chord_tensor, actions_tensor)
        index_map = self.build_action_index_map()[0:10]
        # print(len(index_map))
        if len(index_map) == 0:
            return None  # no actions possible
        
        if random.random() < epsilon:
            flat_index = random.randint(0, len(index_map) - 1)
        else:
            q_values = self.model(chord_tensor, actions_tensor).detach().squeeze(0)[0:len(index_map)]  # shape: (num_actions,)
            flat_index = q_values.squeeze(0).argmax().item()

        # reward_before = self.evaluate_tree()
        i, j = index_map[flat_index]
        self.apply_rule_index(i, j)
        # reward_after = self.evaluate_tree()
        last_rule = self.applied_rules[-1]
        # reward = prob_dict.get(last_rule.make_hashable(), 1e-10)  # Use same small value as in evaluate_tree
        # delta_reward = reward_after - reward_before
        next_chord_tensor, next_actions_tensor = self.get_state_tensor()
        # reward = self.evaluate_tree() if self.is_terminal() else np.log(prob_dict.get(last_rule.make_hashable(), 1e-10))
        reward = np.log(prob_dict.get(last_rule.make_hashable(), 1e-10))
        done = self.is_terminal()
        # if done:
        #     delta_reward = self.evaluate_tree()
        return {
        "state": chord_tensor,
        "actions": actions_tensor,
        "action_index": flat_index,
        "reward": reward,
        "next_state": next_chord_tensor,
        "next_actions": next_actions_tensor,
        "done": done
    }
    

    def nn_simulate(self, epsilon=0.1):
        while not self.is_terminal():
            result = self.step()
            if result is None:
                break
 

    def add_model(self, model):
        self.model = model

    def is_terminal(self):
        return len(self.current_state) == 1

    def random_baseline_step(self):
        chord_tensor, actions_tensor = self.get_state_tensor()
        index_map = self.build_action_index_map()

        if len(index_map) == 0:
            return None
        flat_index = random.randint(0, len(index_map) - 1)
        i, j = index_map[flat_index]
        self.apply_rule_index(i, j)

    def simulate_random_baseline(self):
        while not self.is_terminal():
            self.random_baseline_step()

    def simulate_greedy_baseline(self):
        while not self.is_terminal():
            actions = self.get_actions()
            index_map = self.build_action_index_map()
            max_prob = float('-inf')
            max_i = 0
            max_j = 0
            for i, rule_list in enumerate(actions):
                for j, rule in enumerate(rule_list):
                    prob = prob_dict.get(rule.make_hashable(), 1e-10)  # Use same small value as in evaluate_tree
                    if prob > max_prob:
                        max_prob = prob
                        max_i = i
                        max_j = j
            if len(index_map) == 0:
                break
            self.apply_rule_index(max_i, max_j)

    def evaluate_tree(self):
        log_probs = 0
        for rule in self.applied_rules:
            log_probs += np.log(prob_dict.get(rule.make_hashable(), 1e-10))  # Add a small value to avoid log(0)

        return log_probs

# %%
def decode_state_tensor(chord_tensor, actions_tensor):
    # Constants from encoding
    QUALITY_VOCAB = ['major', 'minor', 'sus', 'unknown']
    INTERVAL_VOCAB = [str(i) for i in range(12)]

    def one_hot_decode(vec, vocab):
        idx = int(np.argmax(vec))
        return vocab[idx]

    def decode_chord(chord_vec):
        # Assuming Chord.encode_chord() returns a known-length flat vector
        # You'll need to know how many features make up one chord
        # Example assumes each chord is encoded as 12 pitch classes + 1 quality index (simplified)
        root = np.argmax(chord_vec[:12])
        quality_idx = np.argmax(chord_vec[12:12 + len(QUALITY_VOCAB)])
        quality = QUALITY_VOCAB[quality_idx]
        return f"{root}_{quality}"

    def decode_action(action_vec):
        split = np.array_split(action_vec, [len(QUALITY_VOCAB),
                                            len(QUALITY_VOCAB) + len(INTERVAL_VOCAB),
                                            len(QUALITY_VOCAB) + len(INTERVAL_VOCAB)*2,
                                            len(QUALITY_VOCAB) + len(INTERVAL_VOCAB)*2 + len(QUALITY_VOCAB)])
        parent_vec, interval1_vec, quality1_vec, interval2_vec, quality2_vec = split
        return {
            "parent_quality": one_hot_decode(parent_vec, QUALITY_VOCAB),
            "child_interval_1": one_hot_decode(interval1_vec, INTERVAL_VOCAB),
            "child_quality_1": one_hot_decode(quality1_vec, QUALITY_VOCAB),
            "child_interval_2": one_hot_decode(interval2_vec, INTERVAL_VOCAB),
            "child_quality_2": one_hot_decode(quality2_vec, QUALITY_VOCAB),
        }

    chord_tensor_np = chord_tensor.squeeze(0).detach().numpy()
    actions_tensor_np = actions_tensor.squeeze(0).detach().numpy()

    # Decode chords
    chord_size = len(Chord.encode_chord("0_major"))  # adjust if you have a different encoding
    chords = []
    for i in range(0, len(chord_tensor_np), chord_size):
        chunk = chord_tensor_np[i:i + chord_size]
        if not np.allclose(chunk, 0):  # skip padding
            chords.append(decode_chord(chunk))

    # Decode actions
    rule_size = len(actions_tensor_np[0])
    actions = []
    for action_vec in actions_tensor_np:
        if not np.allclose(action_vec, 0):  # skip padding
            actions.append(decode_action(action_vec))

    return chords, actions

# %%
chords = ['Cmaj7', 'Dmin7', 'Emin7', 'Fmaj7', 'G7', 'Amin7b5', 'Bbsus']
env = Environment(chords)
env.simulate_greedy_baseline()
env.evaluate_tree()
# Out:
# -26.116676455677904

# %%
chords = ['C^', 'Dmin7', 'Emin7', 'F^7', 'G7', 'Amin7b5', 'Bbsus']
env = Environment(chords)

# %%
chords = ['Cmaj7', 'Dmin7', 'Emin7', 'Fmaj7', 'G7', 'Amin7b5', 'Bbsus']
env = Environment(chords)
env.simulate_random_baseline()
env.evaluate_tree()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 chords = ['Cmaj7', 'Dmin7', 'Emin7', 'Fmaj7', 'G7', 'Amin7b5', 'Bbsus']
#       2 env = Environment(chords)
# ----> 3 env.simulate_random_baseline()
#       4 env.evaluate_tree()
#
# Cell In[16], line 235, in Environment.simulate_random_baseline(self)
#     233 def simulate_random_baseline(self):
#     234     while not self.is_terminal():
# --> 235         self.random_baseline_step()
#
# Cell In[16], line 224, in Environment.random_baseline_step(self)
#     223 def random_baseline_step(self):
# --> 224     chord_tensor, actions_tensor = self.get_state_tensor()
#     225     index_map = self.build_action_index_map()
#     227     if len(index_map) == 0:
#
# Cell In[16], line 150, in Environment.get_state_tensor(self)
#     147     chord_vector.append([0] * len(chord_vector[0]))
#     149 flat_chord_vector = [val for chord in chord_vector for val in chord]
# --> 150 chord_tensor = torch.tensor(flat_chord_vector, dtype=torch.float32).unsqueeze(0)
#     152 actions = self.get_actions()
#     153 action_vector = []
#
# NameError: name 'torch' is not defined

# %%
chords_dataset[0]
# Out:
# ['D7', 'G^7', 'F#m7', 'Bm', 'Em7', 'Bm', 'Am7']

# %%
len(chords_dataset)
# Out:
# 1170

# %%
greedy = []
random_vals = []
nn_vals = []
counter = 0
for chord in chords_dataset:
    counter += 1
    print('num ',counter)
    print('a')
    env = Environment(chord)
    env.add_model(model)
    env.simulate_random_baseline()
    random_vals.append(env.evaluate_tree())
    print('b')
    env = Environment(chord)
    env.add_model(model)
    env.simulate_greedy_baseline()
    greedy.append(env.evaluate_tree())
    print('c')
    env = Environment(chord)
    env.add_model(model)
    env.nn_simulate()
    nn_vals.append(env.evaluate_tree())
# Out:
# num  1
# a
# b
# c
# num  2
# a
# b
# c
# num  3
# a
# b
# c
# num  4
# a
# b
# c
# num  5
# a
# b
# c
# num  6
# a
# b
# c
# num  7
# a
# b
# c
# num  8
# a
# b
# c
# num  9
# a
# b
# c
# num  10
# a
# b
# c
# num  11
# a
# b
# c
# num  12
# a
# b
# c
# num  13
# a
# b
# c
# num  14
# a
# b
# c
# num  15
# a
# b
# c
# num  16
# a
# b
# c
# num  17
# a
# b
# c
# num  18
# a
# b
# c
# num  19
# a
# b
# c
# num  20
# a
# b
# c
# num  21
# a
# b
# c
# num  22
# a
# b
# c
# num  23
# a
# b
# c
# num  24
# a
# b
# c
# num  25
# a
# b
# c
# num  26
# a
# b
# c
# num  27
# a
# b
# c
# num  28
# a
# b
# c
# num  29
# a
# b
# c
# num  30
# a
# b
# c
# num  31
# a
# b
# c
# num  32
# a
# b
# c
# num  33
# a
# b
# c
# num  34
# a
# b
# c
# num  35
# a
# b
# c
# num  36
# a
# b
# c
# num  37
# a
# b
# c
# num  38
# a
# b
# c
# num  39
# a
# b
# c
# num  40
# a
# b
# c
# num  41
# a
# b
# c
# num  42
# a
# b
# c
# num  43
# a
# b
# c
# num  44
# a
# b
# c
# num  45
# a
# b
# c
# num  46
# a
# b
# c
# num  47
# a
# b
# c
# num  48
# a
# b
# c
# num  49
# a
# b
# c
# num  50
# a
# b
# c
# num  51
# a
# b
# c
# num  52
# a
# b
# c
# num  53
# a
# b
# c
# num  54
# a
# b
# c
# num  55
# a
# b
# c
# num  56
# a
# b
# c
# num  57
# a
# b
# c
# num  58
# a
# b
# c
# num  59
# a
# b
# c
# num  60
# a
# b
# c
# num  61
# a
# b
# c
# num  62
# a
# b
# c
# num  63
# a
# b
# c
# num  64
# a
# b
# c
# num  65
# a
# b
# c
# num  66
# a
# b
# c
# num  67
# a
# b
# c
# num  68
# a
# b
# c
# num  69
# a
# b
# c
# num  70
# a
# b
# c
# num  71
# a
# b
# c
# num  72
# a
# b
# c
# num  73
# a
# b
# c
# num  74
# a
# b
# c
# num  75
# a
# b
# c
# num  76
# a
# b
# c
# num  77
# a
# b
# c
# num  78
# a
# b
# c
# num  79
# a
# b
# c
# num  80
# a
# b
# c
# num  81
# a
# b
# c
# num  82
# a
# b
# c
# num  83
# a
# b
# c
# num  84
# a
# b
# c
# num  85
# a
# b
# c
# num  86
# a
# b
# c
# num  87
# a
# b
# c
# num  88
# a
# b
# c
# num  89
# a
# b
# c
# num  90
# a
# b
# c
# num  91
# a
# b
# c
# num  92
# a
# b
# c
# num  93
# a
# b
# c
# num  94
# a
# b
# c
# num  95
# a
# b
# c
# num  96
# a
# b
# c
# num  97
# a
# b
# c
# num  98
# a
# b
# c
# num  99
# a
# b
# c
# num  100
# a
# b
# c
# num  101
# a
# b
# c
# num  102
# a
# b
# c
# num  103
# a
# b
# c
# num  104
# a
# b
# c
# num  105
# a
# b
# c
# num  106
# a
# b
# c
# num  107
# a
# b
# c
# num  108
# a
# b
# c
# num  109
# a
# b
# c
# num  110
# a
# b
# c
# num  111
# a
# b
# c
# num  112
# a
# b
# c
# num  113
# a
# b
# c
# num  114
# a
# b
# c
# num  115
# a
# b
# c
# num  116
# a
# b
# c
# num  117
# a
# b
# c
# num  118
# a
# b
# c
# num  119
# a
# b
# c
# num  120
# a
# b
# c
# num  121
# a
# b
# c
# num  122
# a
# b
# c
# num  123
# a
# b
# c
# num  124
# a
# b
# c
# num  125
# a
# b
# c
# num  126
# a
# b
# c
# num  127
# a
# b
# c
# num  128
# a
# b
# c
# num  129
# a
# b
# c
# num  130
# a
# b
# c
# num  131
# a
# b
# c
# num  132
# a
# b
# c
# num  133
# a
# b
# c
# num  134
# a
# b
# c
# num  135
# a
# b
# c
# num  136
# a
# b
# c
# num  137
# a
# b
# c
# num  138
# a
# b
# c
# num  139
# a
# b
# c
# num  140
# a
# b
# c
# num  141
# a
# b
# c
# num  142
# a
# b
# c
# num  143
# a
# b
# c
# num  144
# a
# b
# c
# num  145
# a
# b
# c
# num  146
# a
# b
# c
# num  147
# a
# b
# c
# num  148
# a
# b
# c
# num  149
# a
# b
# c
# num  150
# a
# b
# c
# num  151
# a
# b
# c
# num  152
# a
# b
# c
# num  153
# a
# b
# c
# num  154
# a
# b
# c
# num  155
# a
# b
# c
# num  156
# a
# b
# c
# num  157
# a
# b
# c
# num  158
# a
# b
# c
# num  159
# a
# b
# c
# num  160
# a
# b
# c
# num  161
# a
# b
# c
# num  162
# a
# b
# c
# num  163
# a
# b
# c
# num  164
# a
# b
# c
# num  165
# a
# b
# c
# num  166
# a
# b
# c
# num  167
# a
# b
# c
# num  168
# a
# b
# c
# num  169
# a
# b
# c
# num  170
# a
# b
# c
# num  171
# a
# b
# c
# num  172
# a
# b
# c
# num  173
# a
# b
# c
# num  174
# a
# b
# c
# num  175
# a
# b
# c
# num  176
# a
# b
# c
# num  177
# a
# b
# c
# num  178
# a
# b
# c
# num  179
# a
# b
# c
# num  180
# a
# b
# c
# num  181
# a
# b
# c
# num  182
# a
# b
# c
# num  183
# a
# b
# c
# num  184
# a
# b
# c
# num  185
# a
# b
# c
# num  186
# a
# b
# c
# num  187
# a
# b
# c
# num  188
# a
# b
# c
# num  189
# a
# b
# c
# num  190
# a
# b
# c
# num  191
# a
# b
# c
# num  192
# a
# b
# c
# num  193
# a
# b
# c
# num  194
# a
# b
# c
# num  195
# a
# b
# c
# num  196
# a
# b
# c
# num  197
# a
# b
# c
# num  198
# a
# b
# c
# num  199
# a
# b
# c
# num  200
# a
# b
# c
# num  201
# a
# b
# c
# num  202
# a
# b
# c
# num  203
# a
# b
# c
# num  204
# a
# b
# c
# num  205
# a
# b
# c
# num  206
# a
# b
# c
# num  207
# a
# b
# c
# num  208
# a
# b
# c
# num  209
# a
# b
# c
# num  210
# a
# b
# c
# num  211
# a
# b
# c
# num  212
# a
# b
# c
# num  213
# a
# b
# c
# num  214
# a
# b
# c
# num  215
# a
# b
# c
# num  216
# a
# b
# c
# num  217
# a
# b
# c
# num  218
# a
# b
# c
# num  219
# a
# b
# c
# num  220
# a
# b
# c
# num  221
# a
# b
# c
# num  222
# a
# b
# c
# num  223
# a
# b
# c
# num  224
# a
# b
# c
# num  225
# a
# b
# c
# num  226
# a
# b
# c
# num  227
# a
# b
# c
# num  228
# a
# b
# c
# num  229
# a
# b
# c
# num  230
# a
# b
# c
# num  231
# a
# b
# c
# num  232
# a
# b
# c
# num  233
# a
# b
# c
# num  234
# a
# b
# c
# num  235
# a
# b
# c
# num  236
# a
# b
# c
# num  237
# a
# b
# c
# num  238
# a
# b
# c
# num  239
# a
# b
# c
# num  240
# a
# b
# c
# num  241
# a
# b
# c
# num  242
# a
# b
# c
# num  243
# a
# b
# c
# num  244
# a
# b
# c
# num  245
# a
# b
# c
# num  246
# a
# b
# c
# num  247
# a
# b
# c
# num  248
# a
# b
# c
# num  249
# a
# b
# c
# num  250
# a
# b
# c
# num  251
# a
# b
# c
# num  252
# a
# b
# c
# num  253
# a
# b
# c
# num  254
# a
# b
# c
# num  255
# a
# b
# c
# num  256
# a
# b
# c
# num  257
# a
# b
# c
# num  258
# a
# b
# c
# num  259
# a
# b
# c
# num  260
# a
# b
# c
# num  261
# a
# b
# c
# num  262
# a
# b
# c
# num  263
# a
# b
# c
# num  264
# a
# b
# c
# num  265
# a
# b
# c
# num  266
# a
# b
# c
# num  267
# a
# b
# c
# num  268
# a
# b
# c
# num  269
# a
# b
# c
# num  270
# a
# b
# c
# num  271
# a
# b
# c
# num  272
# a
# b
# c
# num  273
# a
# b
# c
# num  274
# a
# b
# c
# num  275
# a
# b
# c
# num  276
# a
# b
# c
# num  277
# a
# b
# c
# num  278
# a
# b
# c
# num  279
# a
# b
# c
# num  280
# a
# b
# c
# num  281
# a
# b
# c
# num  282
# a
# b
# c
# num  283
# a
# b
# c
# num  284
# a
# b
# c
# num  285
# a
# b
# c
# num  286
# a
# b
# c
# num  287
# a
# b
# c
# num  288
# a
# b
# c
# num  289
# a
# b
# c
# num  290
# a
# b
# c
# num  291
# a
# b
# c
# num  292
# a
# b
# c
# num  293
# a
# b
# c
# num  294
# a
# b
# c
# num  295
# a
# b
# c
# num  296
# a
# b
# c
# num  297
# a
# b
# c
# num  298
# a
# b
# c
# num  299
# a
# b
# c
# num  300
# a
# b
# c
# num  301
# a
# b
# c
# num  302
# a
# b
# c
# num  303
# a
# b
# c
# num  304
# a
# b
# c
# num  305
# a
# b
# c
# num  306
# a
# b
# c
# num  307
# a
# b
# c
# num  308
# a
# b
# c
# num  309
# a
# b
# c
# num  310
# a
# b
# c
# num  311
# a
# b
# c
# num  312
# a
# b
# c
# num  313
# a
# b
# c
# num  314
# a
# b
# c
# num  315
# a
# b
# c
# num  316
# a
# b
# c
# num  317
# a
# b
# c
# num  318
# a
# b
# c
# num  319
# a
# b
# c
# num  320
# a
# b
# c
# num  321
# a
# b
# c
# num  322
# a
# b
# c
# num  323
# a
# b
# c
# num  324
# a
# b
# c
# num  325
# a
# b
# c
# num  326
# a
# b
# c
# num  327
# a
# b
# c
# num  328
# a
# b
# c
# num  329
# a
# b
# c
# num  330
# a
# b
# c
# num  331
# a
# b
# c
# num  332
# a
# b
# c
# num  333
# a
# b
# c
# num  334
# a
# b
# c
# num  335
# a
# b
# c
# num  336
# a
# b
# c
# num  337
# a
# b
# c
# num  338
# a
# b
# c
# num  339
# a
# b
# c
# num  340
# a
# b
# c
# num  341
# a
# b
# c
# num  342
# a
# b
# c
# num  343
# a
# b
# c
# num  344
# a
# b
# c
# num  345
# a
# b
# c
# num  346
# a
# b
# c
# num  347
# a
# b
# c
# num  348
# a
# b
# c
# num  349
# a
# b
# c
# num  350
# a
# b
# c
# num  351
# a
# b
# c
# num  352
# a
# b
# c
# num  353
# a
# b
# c
# num  354
# a
# b
# c
# num  355
# a
# b
# c
# num  356
# a
# b
# c
# num  357
# a
# b
# c
# num  358
# a
# b
# c
# num  359
# a
# b
# c
# num  360
# a
# b
# c
# num  361
# a
# b
# c
# num  362
# a
# b
# c
# num  363
# a
# b
# c
# num  364
# a
# b
# c
# num  365
# a
# b
# c
# num  366
# a
# b
# c
# num  367
# a
# b
# c
# num  368
# a
# b
# c
# num  369
# a
# b
# c
# num  370
# a
# b
# c
# num  371
# a
# b
# c
# num  372
# a
# b
# c
# num  373
# a
# b
# c
# num  374
# a
# b
# c
# num  375
# a
# b
# c
# num  376
# a
# b
# c
# num  377
# a
# b
# c
# num  378
# a
# b
# c
# num  379
# a
# b
# c
# num  380
# a
# b
# c
# num  381
# a
# b
# c
# num  382
# a
# b
# c
# num  383
# a
# b
# c
# num  384
# a
# b
# c
# num  385
# a
# b
# c
# num  386
# a
# b
# c
# num  387
# a
# b
# c
# num  388
# a
# b
# c
# num  389
# a
# b
# c
# num  390
# a
# b
# c
# num  391
# a
# b
# c
# num  392
# a
# b
# c
# num  393
# a
# b
# c
# num  394
# a
# b
# c
# num  395
# a
# b
# c
# num  396
# a
# b
# c
# num  397
# a
# b
# c
# num  398
# a
# b
# c
# num  399
# a
# b
# c
# num  400
# a
# b
# c
# num  401
# a
# b
# c
# num  402
# a
# b
# c
# num  403
# a
# b
# c
# num  404
# a
# b
# c
# num  405
# a
# b
# c
# num  406
# a
# b
# c
# num  407
# a
# b
# c
# num  408
# a
# b
# c
# num  409
# a
# b
# c
# num  410
# a
# b
# c
# num  411
# a
# b
# c
# num  412
# a
# b
# c
# num  413
# a
# b
# c
# num  414
# a
# b
# c
# num  415
# a
# b
# c
# num  416
# a
# b
# c
# num  417
# a
# b
# c
# num  418
# a
# b
# c
# num  419
# a
# b
# c
# num  420
# a
# b
# c
# num  421
# a
# b
# c
# num  422
# a
# b
# c
# num  423
# a
# b
# c
# num  424
# a
# b
# c
# num  425
# a
# b
# c
# num  426
# a
# b
# c
# num  427
# a
# b
# c
# num  428
# a
# b
# c
# num  429
# a
# b
# c
# num  430
# a
# b
# c
# num  431
# a
# b
# c
# num  432
# a
# b
# c
# num  433
# a
# b
# c
# num  434
# a
# b
# c
# num  435
# a
# b
# c
# num  436
# a
# b
# c
# num  437
# a
# b
# c
# num  438
# a
# b
# c
# num  439
# a
# b
# c
# num  440
# a
# b
# c
# num  441
# a
# b
# c
# num  442
# a
# b
# c
# num  443
# a
# b
# c
# num  444
# a
# b
# c
# num  445
# a
# b
# c
# num  446
# a
# b
# c
# num  447
# a
# b
# c
# num  448
# a
# b
# c
# num  449
# a
# b
# c
# num  450
# a
# b
# c
# num  451
# a
# b
# c
# num  452
# a
# b
# c
# num  453
# a
# b
# c
# num  454
# a
# b
# c
# num  455
# a
# b
# c
# num  456
# a
# b
# c
# num  457
# a
# b
# c
# num  458
# a
# b
# c
# num  459
# a
# b
# c
# num  460
# a
# b
# c
# num  461
# a
# b
# c
# num  462
# a
# b
# c
# num  463
# a
# b
# c
# num  464
# a
# b
# c
# num  465
# a
# b
# c
# num  466
# a
# b
# c
# num  467
# a
# b
# c
# num  468
# a
# b
# c
# num  469
# a
# b
# c
# num  470
# a
# b
# c
# num  471
# a
# b
# c
# num  472
# a
# b
# c
# num  473
# a
# b
# c
# num  474
# a
# b
# c
# num  475
# a
# b
# c
# num  476
# a
# b
# c
# num  477
# a
# b
# c
# num  478
# a
# b
# c
# num  479
# a
# b
# c
# num  480
# a
# b
# c
# num  481
# a
# b
# c
# num  482
# a
# b
# c
# num  483
# a
# b
# c
# num  484
# a
# b
# c
# num  485
# a
# b
# c
# num  486
# a
# b
# c
# num  487
# a
# b
# c
# num  488
# a
# b
# c
# num  489
# a
# b
# c
# num  490
# a
# b
# c
# num  491
# a
# b
# c
# num  492
# a
# b
# c
# num  493
# a
# b
# c
# num  494
# a
# b
# c
# num  495
# a
# b
# c
# num  496
# a
# b
# c
# num  497
# a
# b
# c
# num  498
# a
# b
# c
# num  499
# a
# b
# c
# num  500
# a
# b
# c
# num  501
# a
# b
# c
# num  502
# a
# b
# c
# num  503
# a
# b
# c
# num  504
# a
# b
# c
# num  505
# a
# b
# c
# num  506
# a
# b
# c
# num  507
# a
# b
# c
# num  508
# a
# b
# c
# num  509
# a
# b
# c
# num  510
# a
# b
# c
# num  511
# a
# b
# c
# num  512
# a
# b
# c
# num  513
# a
# b
# c
# num  514
# a
# b
# c
# num  515
# a
# b
# c
# num  516
# a
# b
# c
# num  517
# a
# b
# c
# num  518
# a
# b
# c
# num  519
# a
# b
# c
# num  520
# a
# b
# c
# num  521
# a
# b
# c
# num  522
# a
# b
# c
# num  523
# a
# b
# c
# num  524
# a
# b
# c
# num  525
# a
# b
# c
# num  526
# a
# b
# c
# num  527
# a
# b
# c
# num  528
# a
# b
# c
# num  529
# a
# b
# c
# num  530
# a
# b
# c
# num  531
# a
# b
# c
# num  532
# a
# b
# c
# num  533
# a
# b
# c
# num  534
# a
# b
# c
# num  535
# a
# b
# c
# num  536
# a
# b
# c
# num  537
# a
# b
# c
# num  538
# a
# b
# c
# num  539
# a
# b
# c
# num  540
# a
# b
# c
# num  541
# a
# b
# c
# num  542
# a
# b
# c
# num  543
# a
# b
# c
# num  544
# a
# b
# c
# num  545
# a
# b
# c
# num  546
# a
# b
# c
# num  547
# a
# b
# c
# num  548
# a
# b
# c
# num  549
# a
# b
# c
# num  550
# a
# b
# c
# num  551
# a
# b
# c
# num  552
# a
# b
# c
# num  553
# a
# b
# c
# num  554
# a
# b
# c
# num  555
# a
# b
# c
# num  556
# a
# b
# c
# num  557
# a
# b
# c
# num  558
# a
# b
# c
# num  559
# a
# b
# c
# num  560
# a
# b
# c
# num  561
# a
# b
# c
# num  562
# a
# b
# c
# num  563
# a
# b
# c
# num  564
# a
# b
# c
# num  565
# a
# b
# c
# num  566
# a
# b
# c
# num  567
# a
# b
# c
# num  568
# a
# b
# c
# num  569
# a
# b
# c
# num  570
# a
# b
# c
# num  571
# a
# b
# c
# num  572
# a
# b
# c
# num  573
# a
# b
# c
# num  574
# a
# b
# c
# num  575
# a
# b
# c
# num  576
# a
# b
# c
# num  577
# a
# b
# c
# num  578
# a
# b
# c
# num  579
# a
# b
# c
# num  580
# a
# b
# c
# num  581
# a
# b
# c
# num  582
# a
# b
# c
# num  583
# a
# b
# c
# num  584
# a
# b
# c
# num  585
# a
# b
# c
# num  586
# a
# b
# c
# num  587
# a
# b
# c
# num  588
# a
# b
# c
# num  589
# a
# b
# c
# num  590
# a
# b
# c
# num  591
# a
# b
# c
# num  592
# a
# b
# c
# num  593
# a
# b
# c
# num  594
# a
# b
# c
# num  595
# a
# b
# c
# num  596
# a
# b
# c
# num  597
# a
# b
# c
# num  598
# a
# b
# c
# num  599
# a
# b
# c
# num  600
# a
# b
# c
# num  601
# a
# b
# c
# num  602
# a
# b
# c
# num  603
# a
# b
# c
# num  604
# a
# b
# c
# num  605
# a
# b
# c
# num  606
# a
# b
# c
# num  607
# a
# b
# c
# num  608
# a
# b
# c
# num  609
# a
# b
# c
# num  610
# a
# b
# c
# num  611
# a
# b
# c
# num  612
# a
# b
# c
# num  613
# a
# b
# c
# num  614
# a
# b
# c
# num  615
# a
# b
# c
# num  616
# a
# b
# c
# num  617
# a
# b
# c
# num  618
# a
# b
# c
# num  619
# a
# b
# c
# num  620
# a
# b
# c
# num  621
# a
# b
# c
# num  622
# a
# b
# c
# num  623
# a
# b
# c
# num  624
# a
# b
# c
# num  625
# a
# b
# c
# num  626
# a
# b
# c
# num  627
# a
# b
# c
# num  628
# a
# b
# c
# num  629
# a
# b
# c
# num  630
# a
# b
# c
# num  631
# a
# b
# c
# num  632
# a
# b
# c
# num  633
# a
# b
# c
# num  634
# a
# b
# c
# num  635
# a
# b
# c
# num  636
# a
# b
# c
# num  637
# a
# b
# c
# num  638
# a
# b
# c
# num  639
# a
# b
# c
# num  640
# a
# b
# c
# num  641
# a
# b
# c
# num  642
# a
# b
# c
# num  643
# a
# b
# c
# num  644
# a
# b
# c
# num  645
# a
# b
# c
# num  646
# a
# b
# c
# num  647
# a
# b
# c
# num  648
# a
# b
# c
# num  649
# a
# b
# c
# num  650
# a
# b
# c
# num  651
# a
# b
# c
# num  652
# a
# b
# c
# num  653
# a
# b
# c
# num  654
# a
# b
# c
# num  655
# a
# b
# c
# num  656
# a
# b
# c
# num  657
# a
# b
# c
# num  658
# a
# b
# c
# num  659
# a
# b
# c
# num  660
# a
# b
# c
# num  661
# a
# b
# c
# num  662
# a
# b
# c
# num  663
# a
# b
# c
# num  664
# a
# b
# c
# num  665
# a
# b
# c
# num  666
# a
# b
# c
# num  667
# a
# b
# c
# num  668
# a
# b
# c
# num  669
# a
# b
# c
# num  670
# a
# b
# c
# num  671
# a
# b
# c
# num  672
# a
# b
# c
# num  673
# a
# b
# c
# num  674
# a
# b
# c
# num  675
# a
# b
# c
# num  676
# a
# b
# c
# num  677
# a
# b
# c
# num  678
# a
# b
# c
# num  679
# a
# b
# c
# num  680
# a
# b
# c
# num  681
# a
# b
# c
# num  682
# a
# b
# c
# num  683
# a
# b
# c
# num  684
# a
# b
# c
# num  685
# a
# b
# c
# num  686
# a
# b
# c
# num  687
# a
# b
# c
# num  688
# a
# b
# c
# num  689
# a
# b
# c
# num  690
# a
# b
# c
# num  691
# a
# b
# c
# num  692
# a
# b
# c
# num  693
# a
# b
# c
# num  694
# a
# b
# c
# num  695
# a
# b
# c
# num  696
# a
# b
# c
# num  697
# a
# b
# c
# num  698
# a
# b
# c
# num  699
# a
# b
# c
# num  700
# a
# b
# c
# num  701
# a
# b
# c
# num  702
# a
# b
# c
# num  703
# a
# b
# c
# num  704
# a
# b
# c
# num  705
# a
# b
# c
# num  706
# a
# b
# c
# num  707
# a
# b
# c
# num  708
# a
# b
# c
# num  709
# a
# b
# c
# num  710
# a
# b
# c
# num  711
# a
# b
# c
# num  712
# a
# b
# c
# num  713
# a
# b
# c
# num  714
# a
# b
# c
# num  715
# a
# b
# c
# num  716
# a
# b
# c
# num  717
# a
# b
# c
# num  718
# a
# b
# c
# num  719
# a
# b
# c
# num  720
# a
# b
# c
# num  721
# a
# b
# c
# num  722
# a
# b
# c
# num  723
# a
# b
# c
# num  724
# a
# b
# c
# num  725
# a
# b
# c
# num  726
# a
# b
# c
# num  727
# a
# b
# c
# num  728
# a
# b
# c
# num  729
# a
# b
# c
# num  730
# a
# b
# c
# num  731
# a
# b
# c
# num  732
# a
# b
# c
# num  733
# a
# b
# c
# num  734
# a
# b
# c
# num  735
# a
# b
# c
# num  736
# a
# b
# c
# num  737
# a
# b
# c
# num  738
# a
# b
# c
# num  739
# a
# b
# c
# num  740
# a
# b
# c
# num  741
# a
# b
# c
# num  742
# a
# b
# c
# num  743
# a
# b
# c
# num  744
# a
# b
# c
# num  745
# a
# b
# c
# num  746
# a
# b
# c
# num  747
# a
# b
# c
# num  748
# a
# b
# c
# num  749
# a
# b
# c
# num  750
# a
# b
# c
# num  751
# a
# b
# c
# num  752
# a
# b
# c
# num  753
# a
# b
# c
# num  754
# a
# b
# c
# num  755
# a
# b
# c
# num  756
# a
# b
# c
# num  757
# a
# b
# c
# num  758
# a
# b
# c
# num  759
# a
# b
# c
# num  760
# a
# b
# c
# num  761
# a
# b
# c
# num  762
# a
# b
# c
# num  763
# a
# b
# c
# num  764
# a
# b
# c
# num  765
# a
# b
# c
# num  766
# a
# b
# c
# num  767
# a
# b
# c
# num  768
# a
# b
# c
# num  769
# a
# b
# c
# num  770
# a
# b
# c
# num  771
# a
# b
# c
# num  772
# a
# b
# c
# num  773
# a
# b
# c
# num  774
# a
# b
# c
# num  775
# a
# b
# c
# num  776
# a
# b
# c
# num  777
# a
# b
# c
# num  778
# a
# b
# c
# num  779
# a
# b
# c
# num  780
# a
# b
# c
# num  781
# a
# b
# c
# num  782
# a
# b
# c
# num  783
# a
# b
# c
# num  784
# a
# b
# c
# num  785
# a
# b
# c
# num  786
# a
# b
# c
# num  787
# a
# b
# c
# num  788
# a
# b
# c
# num  789
# a
# b
# c
# num  790
# a
# b
# c
# num  791
# a
# b
# c
# num  792
# a
# b
# c
# num  793
# a
# b
# c
# num  794
# a
# b
# c
# num  795
# a
# b
# c
# num  796
# a
# b
# c
# num  797
# a
# b
# c
# num  798
# a
# b
# c
# num  799
# a
# b
# c
# num  800
# a
# b
# c
# num  801
# a
# b
# c
# num  802
# a
# b
# c
# num  803
# a
# b
# c
# num  804
# a
# b
# c
# num  805
# a
# b
# c
# num  806
# a
# b
# c
# num  807
# a
# b
# c
# num  808
# a
# b
# c
# num  809
# a
# b
# c
# num  810
# a
# b
# c
# num  811
# a
# b
# c
# num  812
# a
# b
# c
# num  813
# a
# b
# c
# num  814
# a
# b
# c
# num  815
# a
# b
# c
# num  816
# a
# b
# c
# num  817
# a
# b
# c
# num  818
# a
# b
# c
# num  819
# a
# b
# c
# num  820
# a
# b
# c
# num  821
# a
# b
# c
# num  822
# a
# b
# c
# num  823
# a
# b
# c
# num  824
# a
# b
# c
# num  825
# a
# b
# c
# num  826
# a
# b
# c
# num  827
# a
# b
# c
# num  828
# a
# b
# c
# num  829
# a
# b
# c
# num  830
# a
# b
# c
# num  831
# a
# b
# c
# num  832
# a
# b
# c
# num  833
# a
# b
# c
# num  834
# a
# b
# c
# num  835
# a
# b
# c
# num  836
# a
# b
# c
# num  837
# a
# b
# c
# num  838
# a
# b
# c
# num  839
# a
# b
# c
# num  840
# a
# b
# c
# num  841
# a
# b
# c
# num  842
# a
# b
# c
# num  843
# a
# b
# c
# num  844
# a
# b
# c
# num  845
# a
# b
# c
# num  846
# a
# b
# c
# num  847
# a
# b
# c
# num  848
# a
# b
# c
# num  849
# a
# b
# c
# num  850
# a
# b
# c
# num  851
# a
# b
# c
# num  852
# a
# b
# c
# num  853
# a
# b
# c
# num  854
# a
# b
# c
# num  855
# a
# b
# c
# num  856
# a
# b
# c
# num  857
# a
# b
# c
# num  858
# a
# b
# c
# num  859
# a
# b
# c
# num  860
# a
# b
# c
# num  861
# a
# b
# c
# num  862
# a
# b
# c
# num  863
# a
# b
# c
# num  864
# a
# b
# c
# num  865
# a
# b
# c
# num  866
# a
# b
# c
# num  867
# a
# b
# c
# num  868
# a
# b
# c
# num  869
# a
# b
# c
# num  870
# a
# b
# c
# num  871
# a
# b
# c
# num  872
# a
# b
# c
# num  873
# a
# b
# c
# num  874
# a
# b
# c
# num  875
# a
# b
# c
# num  876
# a
# b
# c
# num  877
# a
# b
# c
# num  878
# a
# b
# c
# num  879
# a
# b
# c
# num  880
# a
# b
# c
# num  881
# a
# b
# c
# num  882
# a
# b
# c
# num  883
# a
# b
# c
# num  884
# a
# b
# c
# num  885
# a
# b
# c
# num  886
# a
# b
# c
# num  887
# a
# b
# c
# num  888
# a
# b
# c
# num  889
# a
# b
# c
# num  890
# a
# b
# c
# num  891
# a
# b
# c
# num  892
# a
# b
# c
# num  893
# a
# b
# c
# num  894
# a
# b
# c
# num  895
# a
# b
# c
# num  896
# a
# b
# c
# num  897
# a
# b
# c
# num  898
# a
# b
# c
# num  899
# a
# b
# c
# num  900
# a
# b
# c
# num  901
# a
# b
# c
# num  902
# a
# b
# c
# num  903
# a
# b
# c
# num  904
# a
# b
# c
# num  905
# a
# b
# c
# num  906
# a
# b
# c
# num  907
# a
# b
# c
# num  908
# a
# b
# c
# num  909
# a
# b
# c
# num  910
# a
# b
# c
# num  911
# a
# b
# c
# num  912
# a
# b
# c
# num  913
# a
# b
# c
# num  914
# a
# b
# c
# num  915
# a
# b
# c
# num  916
# a
# b
# c
# num  917
# a
# b
# c
# num  918
# a
# b
# c
# num  919
# a
# b
# c
# num  920
# a
# b
# c
# num  921
# a
# b
# c
# num  922
# a
# b
# c
# num  923
# a
# b
# c
# num  924
# a
# b
# c
# num  925
# a
# b
# c
# num  926
# a
# b
# c
# num  927
# a
# b
# c
# num  928
# a
# b
# c
# num  929
# a
# b
# c
# num  930
# a
# b
# c
# num  931
# a
# b
# c
# num  932
# a
# b
# c
# num  933
# a
# b
# c
# num  934
# a
# b
# c
# num  935
# a
# b
# c
# num  936
# a
# b
# c
# num  937
# a
# b
# c
# num  938
# a
# b
# c
# num  939
# a
# b
# c
# num  940
# a
# b
# c
# num  941
# a
# b
# c
# num  942
# a
# b
# c
# num  943
# a
# b
# c
# num  944
# a
# b
# c
# num  945
# a
# b
# c
# num  946
# a
# b
# c
# num  947
# a
# b
# c
# num  948
# a
# b
# c
# num  949
# a
# b
# c
# num  950
# a
# b
# c
# num  951
# a
# b
# c
# num  952
# a
# b
# c
# num  953
# a
# b
# c
# num  954
# a
# b
# c
# num  955
# a
# b
# c
# num  956
# a
# b
# c
# num  957
# a
# b
# c
# num  958
# a
# b
# c
# num  959
# a
# b
# c
# num  960
# a
# b
# c
# num  961
# a
# b
# c
# num  962
# a
# b
# c
# num  963
# a
# b
# c
# num  964
# a
# b
# c
# num  965
# a
# b
# c
# num  966
# a
# b
# c
# num  967
# a
# b
# c
# num  968
# a
# b
# c
# num  969
# a
# b
# c
# num  970
# a
# b
# c
# num  971
# a
# b
# c
# num  972
# a
# b
# c
# num  973
# a
# b
# c
# num  974
# a
# b
# c
# num  975
# a
# b
# c
# num  976
# a
# b
# c
# num  977
# a
# b
# c
# num  978
# a
# b
# c
# num  979
# a
# b
# c
# num  980
# a
# b
# c
# num  981
# a
# b
# c
# num  982
# a
# b
# c
# num  983
# a
# b
# c
# num  984
# a
# b
# c
# num  985
# a
# b
# c
# num  986
# a
# b
# c
# num  987
# a
# b
# c
# num  988
# a
# b
# c
# num  989
# a
# b
# c
# num  990
# a
# b
# c
# num  991
# a
# b
# c
# num  992
# a
# b
# c
# num  993
# a
# b
# c
# num  994
# a
# b
# c
# num  995
# a
# b
# c
# num  996
# a
# b
# c
# num  997
# a
# b
# c
# num  998
# a
# b
# c
# num  999
# a
# b
# c
# num  1000
# a
# b
# c
# num  1001
# a
# b
# c
# num  1002
# a
# b
# c
# num  1003
# a
# b
# c
# num  1004
# a
# b
# c
# num  1005
# a
# b
# c
# num  1006
# a
# b
# c
# num  1007
# a
# b
# c
# num  1008
# a
# b
# c
# num  1009
# a
# b
# c
# num  1010
# a
# b
# c
# num  1011
# a
# b
# c
# num  1012
# a
# b
# c
# num  1013
# a
# b
# c
# num  1014
# a
# b
# c
# num  1015
# a
# b
# c
# num  1016
# a
# b
# c
# num  1017
# a
# b
# c
# num  1018
# a
# b
# c
# num  1019
# a
# b
# c
# num  1020
# a
# b
# c
# num  1021
# a
# b
# c
# num  1022
# a
# b
# c
# num  1023
# a
# b
# c
# num  1024
# a
# b
# c
# num  1025
# a
# b
# c
# num  1026
# a
# b
# c
# num  1027
# a
# b
# c
# num  1028
# a
# b
# c
# num  1029
# a
# b
# c
# num  1030
# a
# b
# c
# num  1031
# a
# b
# c
# num  1032
# a
# b
# c
# num  1033
# a
# b
# c
# num  1034
# a
# b
# c
# num  1035
# a
# b
# c
# num  1036
# a
# b
# c
# num  1037
# a
# b
# c
# num  1038
# a
# b
# c
# num  1039
# a
# b
# c
# num  1040
# a
# b
# c
# num  1041
# a
# b
# c
# num  1042
# a
# b
# c
# num  1043
# a
# b
# c
# num  1044
# a
# b
# c
# num  1045
# a
# b
# c
# num  1046
# a
# b
# c
# num  1047
# a
# b
# c
# num  1048
# a
# b
# c
# num  1049
# a
# b
# c
# num  1050
# a
# b
# c
# num  1051
# a
# b
# c
# num  1052
# a
# b
# c
# num  1053
# a
# b
# c
# num  1054
# a
# b
# c
# num  1055
# a
# b
# c
# num  1056
# a
# b
# c
# num  1057
# a
# b
# c
# num  1058
# a
# b
# c
# num  1059
# a
# b
# c
# num  1060
# a
# b
# c
# num  1061
# a
# b
# c
# num  1062
# a
# b
# c
# num  1063
# a
# b
# c
# num  1064
# a
# b
# c
# num  1065
# a
# b
# c
# num  1066
# a
# b
# c
# num  1067
# a
# b
# c
# num  1068
# a
# b
# c
# num  1069
# a
# b
# c
# num  1070
# a
# b
# c
# num  1071
# a
# b
# c
# num  1072
# a
# b
# c
# num  1073
# a
# b
# c
# num  1074
# a
# b
# c
# num  1075
# a
# b
# c
# num  1076
# a
# b
# c
# num  1077
# a
# b
# c
# num  1078
# a
# b
# c
# num  1079
# a
# b
# c
# num  1080
# a
# b
# c
# num  1081
# a
# b
# c
# num  1082
# a
# b
# c
# num  1083
# a
# b
# c
# num  1084
# a
# b
# c
# num  1085
# a
# b
# c
# num  1086
# a
# b
# c
# num  1087
# a
# b
# c
# num  1088
# a
# b
# c
# num  1089
# a
# b
# c
# num  1090
# a
# b
# c
# num  1091
# a
# b
# c
# num  1092
# a
# b
# c
# num  1093
# a
# b
# c
# num  1094
# a
# b
# c
# num  1095
# a
# b
# c
# num  1096
# a
# b
# c
# num  1097
# a
# b
# c
# num  1098
# a
# b
# c
# num  1099
# a
# b
# c
# num  1100
# a
# b
# c
# num  1101
# a
# b
# c
# num  1102
# a
# b
# c
# num  1103
# a
# b
# c
# num  1104
# a
# b
# c
# num  1105
# a
# b
# c
# num  1106
# a
# b
# c
# num  1107
# a
# b
# c
# num  1108
# a
# b
# c
# num  1109
# a
# b
# c
# num  1110
# a
# b
# c
# num  1111
# a
# b
# c
# num  1112
# a
# b
# c
# num  1113
# a
# b
# c
# num  1114
# a
# b
# c
# num  1115
# a
# b
# c
# num  1116
# a
# b
# c
# num  1117
# a
# b
# c
# num  1118
# a
# b
# c
# num  1119
# a
# b
# c
# num  1120
# a
# b
# c
# num  1121
# a
# b
# c
# num  1122
# a
# b
# c
# num  1123
# a
# b
# c
# num  1124
# a
# b
# c
# num  1125
# a
# b
# c
# num  1126
# a
# b
# c
# num  1127
# a
# b
# c
# num  1128
# a
# b
# c
# num  1129
# a
# b
# c
# num  1130
# a
# b
# c
# num  1131
# a
# b
# c
# num  1132
# a
# b
# c
# num  1133
# a
# b
# c
# num  1134
# a
# b
# c
# num  1135
# a
# b
# c
# num  1136
# a
# b
# c
# num  1137
# a
# b
# c
# num  1138
# a
# b
# c
# num  1139
# a
# b
# c
# num  1140
# a
# b
# c
# num  1141
# a
# b
# c
# num  1142
# a
# b
# c
# num  1143
# a
# b
# c
# num  1144
# a
# b
# c
# num  1145
# a
# b
# c
# num  1146
# a
# b
# c
# num  1147
# a
# b
# c
# num  1148
# a
# b
# c
# num  1149
# a
# b
# c
# num  1150
# a
# b
# c
# num  1151
# a
# b
# c
# num  1152
# a
# b
# c
# num  1153
# a
# b
# c
# num  1154
# a
# b
# c
# num  1155
# a
# b
# c
# num  1156
# a
# b
# c
# num  1157
# a
# b
# c
# num  1158
# a
# b
# c
# num  1159
# a
# b
# c
# num  1160
# a
# b
# c
# num  1161
# a
# b
# c
# num  1162
# a
# b
# c
# num  1163
# a
# b
# c
# num  1164
# a
# b
# c
# num  1165
# a
# b
# c
# num  1166
# a
# b
# c
# num  1167
# a
# b
# c
# num  1168
# a
# b
# c
# num  1169
# a
# b
# c
# num  1170
# a
# b
# c

# %%
np.mean(greedy)
# Out:
# -124.60714835425685

# %%
np.mean(random_vals)
# Out:
# -270.6164459674597

# %%
np.mean(nn_vals)
# Out:
# -167.27215844990178

# %%
chords = ['Cmaj7', 'Dmin7', 'Emin7', 'Fmaj7', 'G7', 'Amin7b5', 'Bbsus']
env = Environment(chords)
env.add_model(model)
env.simulate_greedy_baseline()
env.evaluate_tree()
# Out:
# -26.116676455677904

# %%
chords = ['C^', 'D^7', 'Emin7', 'Fmaj7', 'G7', 'Amin7b5', 'Bbsus']
env = Environment(chords)

# %%
env.get_actions()
# Out:
# [[Rule(parent_quality=major, child_intervals=['10', '0'], child_qualities=['major', 'major']),
#   Rule(parent_quality=major, child_intervals=['0', '2'], child_qualities=['major', 'major'])],
#  [Rule(parent_quality=minor, child_intervals=['10', '0'], child_qualities=['major', 'minor']),
#   Rule(parent_quality=major, child_intervals=['0', '2'], child_qualities=['major', 'minor']),
#   Rule(parent_quality=minor, child_intervals=['0', '2'], child_qualities=['major', 'minor']),
#   Rule(parent_quality=major, child_intervals=['10', '0'], child_qualities=['major', 'minor'])],
#  [Rule(parent_quality=minor, child_intervals=['0', '1'], child_qualities=['minor', 'minor']),
#   Rule(parent_quality=minor, child_intervals=['11', '0'], child_qualities=['minor', 'minor'])],
#  [Rule(parent_quality=major, child_intervals=['10', '0'], child_qualities=['minor', 'major']),
#   Rule(parent_quality=major, child_intervals=['0', '2'], child_qualities=['minor', 'major']),
#   Rule(parent_quality=minor, child_intervals=['0', '2'], child_qualities=['minor', 'major']),
#   Rule(parent_quality=minor, child_intervals=['10', '0'], child_qualities=['minor', 'major'])],
#  [Rule(parent_quality=minor, child_intervals=['10', '0'], child_qualities=['major', 'minor']),
#   Rule(parent_quality=major, child_intervals=['0', '2'], child_qualities=['major', 'minor']),
#   Rule(parent_quality=minor, child_intervals=['0', '2'], child_qualities=['major', 'minor']),
#   Rule(parent_quality=major, child_intervals=['10', '0'], child_qualities=['major', 'minor'])],
#  [Rule(parent_quality=minor, child_intervals=['0', '1'], child_qualities=['minor', 'sus']),
#   Rule(parent_quality=sus, child_intervals=['0', '1'], child_qualities=['minor', 'sus']),
#   Rule(parent_quality=minor, child_intervals=['11', '0'], child_qualities=['minor', 'sus']),
#   Rule(parent_quality=sus, child_intervals=['11', '0'], child_qualities=['minor', 'sus'])]]

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and test sets (80-20 split)
train_ccts, test_ccts = train_test_split(ccts, test_size=0.2, random_state=42)

print(f"Training set size: {len(train_ccts)}")
print(f"Test set size: {len(test_ccts)}")
# Out:
# Training set size: 120
# Test set size: 30

# %%
class ReplayBuffer:
    def __init__(self, capacity=10000):
        self.buffer = []
        self.capacity = capacity

    def add(self, transition):
        self.buffer.append(transition)
        if len(self.buffer) > self.capacity:
            self.buffer.pop(0)

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

# %%
import torch.nn as nn

def train_on_batch(model, optimizer, batch, gamma=0.99):
    hist_batch = torch.cat([b["state"] for b in batch])
    actions_batch = torch.cat([b["actions"] for b in batch])
    next_hist_batch = torch.cat([b["next_state"] for b in batch])
    next_actions_batch = torch.cat([b["next_actions"] for b in batch])
    
    action_indices = torch.tensor([b["action_index"] for b in batch]).unsqueeze(1)
    rewards = torch.tensor([b["reward"] for b in batch], dtype=torch.float32)
    dones = torch.tensor([b["done"] for b in batch], dtype=torch.bool)

    q_values = model(hist_batch, actions_batch)
    q_chosen = q_values.gather(1, action_indices).squeeze(1)

    with torch.no_grad():
        next_q_values = model(next_hist_batch, next_actions_batch)  
        next_q_max = next_q_values.max(dim=1)[0]
        target_q = rewards + gamma * next_q_max * (~dones)

    loss = torch.nn.SmoothL1Loss()(q_chosen, target_q)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    # print("Sample rewards:", rewards[:5])
    # print("Sample dones:", dones[:5])
    # print("Sample target Q:", target_q[:5])
    # print("Sample chosen Q:", q_chosen[:5])
    # print("Loss:", loss.item())

    return loss.item()

# %%
def train_model(model, dataset, num_episodes=1000, batch_size=32, gamma=0.99):
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
    buffer = ReplayBuffer(capacity=5000)

    for episode in range(num_episodes):
        # Random starting sequence
        chord_seq = random.choice(dataset)
        env = Environment(chord_seq)
        env.add_model(model)
        loss = None
        while not env.is_terminal():
            transition = env.step(epsilon=0.3)
            if transition and transition["next_actions"].numel() > 0:
                buffer.add(transition)

            if len(buffer) >= batch_size:
                batch = buffer.sample(batch_size)
                loss = train_on_batch(model, optimizer, batch, gamma)

        if episode % 10 == 0:
            if loss:
                print(f"Episode {episode} complete | Last loss: {loss:.4f}")

# %%
model = DQN(history_dim=160, action_dim=36)

# %%
chords_dataset = list(data['chords'])

# %%
train_model(model, chords_dataset, num_episodes=2000, batch_size=32, gamma=0.99)
# Out:
# Episode 0 complete | Last loss: 4.3394
# Episode 10 complete | Last loss: 1.4783
# Episode 20 complete | Last loss: 4.3424
# Episode 30 complete | Last loss: 3.9391
# Episode 40 complete | Last loss: 8.3106
# Episode 50 complete | Last loss: 7.3341
# Episode 60 complete | Last loss: 0.8100
# Episode 70 complete | Last loss: 4.4357
# Episode 80 complete | Last loss: 1.5888
# Episode 90 complete | Last loss: 1.0954
# Episode 100 complete | Last loss: 0.6362
# Episode 110 complete | Last loss: 2.5546
# Episode 120 complete | Last loss: 2.1352
# Episode 130 complete | Last loss: 2.5209
# Episode 140 complete | Last loss: 1.8690
# Episode 150 complete | Last loss: 1.6016
# Episode 160 complete | Last loss: 6.4681
# Episode 170 complete | Last loss: 2.2542
# Episode 180 complete | Last loss: 3.3504
# Episode 190 complete | Last loss: 2.0882
# Episode 200 complete | Last loss: 2.1531
# Episode 210 complete | Last loss: 4.4122
# Episode 220 complete | Last loss: 2.6154
# Episode 230 complete | Last loss: 1.5049
# Episode 240 complete | Last loss: 1.3151
# Episode 250 complete | Last loss: 4.8802
# Episode 260 complete | Last loss: 1.8961
# Episode 270 complete | Last loss: 4.5632
# Episode 280 complete | Last loss: 7.1308
# Episode 290 complete | Last loss: 2.8119
# Episode 300 complete | Last loss: 1.1932
# Episode 310 complete | Last loss: 3.5609
# Episode 320 complete | Last loss: 1.9121
# Episode 330 complete | Last loss: 1.2238
# Episode 340 complete | Last loss: 2.4593
# Episode 350 complete | Last loss: 1.6215
# Episode 360 complete | Last loss: 2.0600
# Episode 370 complete | Last loss: 1.7771
# Episode 380 complete | Last loss: 1.3788
# Episode 390 complete | Last loss: 1.7508
# Episode 400 complete | Last loss: 1.9449
# Episode 410 complete | Last loss: 1.4590
# Episode 420 complete | Last loss: 2.0942
# Episode 430 complete | Last loss: 1.0819
# Episode 440 complete | Last loss: 1.6483
# Episode 450 complete | Last loss: 1.3236
# Episode 460 complete | Last loss: 2.3225
# Episode 470 complete | Last loss: 1.3333
# Episode 480 complete | Last loss: 2.3730
# Episode 490 complete | Last loss: 0.9175
# Episode 500 complete | Last loss: 2.6819
# Episode 510 complete | Last loss: 0.6252
# Episode 520 complete | Last loss: 1.5321
# Episode 530 complete | Last loss: 1.6503
# Episode 540 complete | Last loss: 1.8381
# Episode 550 complete | Last loss: 2.0572
# Episode 560 complete | Last loss: 1.3417
# Episode 570 complete | Last loss: 2.5115
# Episode 580 complete | Last loss: 2.3431
# Episode 590 complete | Last loss: 2.2562
# Episode 600 complete | Last loss: 1.9481
# Episode 610 complete | Last loss: 1.7464
# Episode 620 complete | Last loss: 1.8212
# Episode 630 complete | Last loss: 0.9855
# Episode 640 complete | Last loss: 4.2223
# Episode 650 complete | Last loss: 2.0562
# Episode 660 complete | Last loss: 1.1795
# Episode 670 complete | Last loss: 2.8592
# Episode 680 complete | Last loss: 1.7155
# Episode 690 complete | Last loss: 1.4901
# Episode 700 complete | Last loss: 1.3624
# Episode 710 complete | Last loss: 1.8385
# Episode 720 complete | Last loss: 1.1765
# Episode 730 complete | Last loss: 1.4087
# Episode 740 complete | Last loss: 0.9013
# Episode 750 complete | Last loss: 0.8567
# Episode 760 complete | Last loss: 0.6802
# Episode 770 complete | Last loss: 1.8954
# Episode 780 complete | Last loss: 1.5493
# Episode 790 complete | Last loss: 1.1133
# Episode 800 complete | Last loss: 0.9687
# Episode 810 complete | Last loss: 1.1619
# Episode 820 complete | Last loss: 1.0387
# Episode 830 complete | Last loss: 1.5932
# Episode 840 complete | Last loss: 1.3313
# Episode 850 complete | Last loss: 1.7074
# Episode 860 complete | Last loss: 1.0522
# Episode 870 complete | Last loss: 2.0292
# Episode 880 complete | Last loss: 1.9943
# Episode 890 complete | Last loss: 2.9294
# Episode 900 complete | Last loss: 1.5805
# Episode 910 complete | Last loss: 3.0259
# Episode 920 complete | Last loss: 2.3980
# Episode 930 complete | Last loss: 2.9880
# Episode 940 complete | Last loss: 2.7744
# Episode 950 complete | Last loss: 1.2460
# Episode 960 complete | Last loss: 2.2161
# Episode 970 complete | Last loss: 3.4040
# Episode 980 complete | Last loss: 5.3388
# Episode 990 complete | Last loss: 1.5026
# Episode 1000 complete | Last loss: 1.1569
# Episode 1010 complete | Last loss: 0.9203
# Episode 1020 complete | Last loss: 1.7007
# Episode 1030 complete | Last loss: 1.7277
# Episode 1040 complete | Last loss: 2.2021
# Episode 1050 complete | Last loss: 1.3051
# Episode 1060 complete | Last loss: 2.1425
# Episode 1070 complete | Last loss: 1.0780
# Episode 1080 complete | Last loss: 1.3606
# Episode 1090 complete | Last loss: 1.2539
# Episode 1100 complete | Last loss: 0.8812
# Episode 1110 complete | Last loss: 1.9118
# Episode 1120 complete | Last loss: 3.6386
# Episode 1130 complete | Last loss: 2.4276
# Episode 1140 complete | Last loss: 1.9309
# Episode 1150 complete | Last loss: 1.8100
# Episode 1160 complete | Last loss: 3.4873
# Episode 1170 complete | Last loss: 1.0842
# Episode 1180 complete | Last loss: 2.8657
# Episode 1190 complete | Last loss: 3.9381
# Episode 1200 complete | Last loss: 5.5682
# Episode 1210 complete | Last loss: 4.7384
# Episode 1220 complete | Last loss: 2.0030
# Episode 1230 complete | Last loss: 1.4911
# Episode 1240 complete | Last loss: 1.5296
# Episode 1250 complete | Last loss: 2.2218
# Episode 1260 complete | Last loss: 1.0168
# Episode 1270 complete | Last loss: 3.3176
# Episode 1280 complete | Last loss: 1.3846
# Episode 1290 complete | Last loss: 2.3466
# Episode 1300 complete | Last loss: 1.8126
# Episode 1310 complete | Last loss: 2.2431
# Episode 1320 complete | Last loss: 5.1417
# Episode 1330 complete | Last loss: 3.8087
# Episode 1340 complete | Last loss: 3.9027
# Episode 1350 complete | Last loss: 1.3243
# Episode 1360 complete | Last loss: 0.8704
# Episode 1370 complete | Last loss: 2.6318
# Episode 1380 complete | Last loss: 3.8267
# Episode 1390 complete | Last loss: 0.9919
# Episode 1400 complete | Last loss: 6.3477
# Episode 1410 complete | Last loss: 2.3765
# Episode 1420 complete | Last loss: 2.7163
# Episode 1430 complete | Last loss: 0.8201
# Episode 1440 complete | Last loss: 1.6366
# Episode 1450 complete | Last loss: 1.0540
# Episode 1460 complete | Last loss: 1.6493
# Episode 1470 complete | Last loss: 1.2636
# Episode 1480 complete | Last loss: 0.7881
# Episode 1490 complete | Last loss: 1.4045
# Episode 1500 complete | Last loss: 1.3956
# Episode 1510 complete | Last loss: 2.0261
# Episode 1520 complete | Last loss: 2.0078
# Episode 1530 complete | Last loss: 1.2834
# Episode 1540 complete | Last loss: 2.1973
# Episode 1550 complete | Last loss: 1.4557
# Episode 1560 complete | Last loss: 1.3964
# Episode 1570 complete | Last loss: 1.9896
# Episode 1580 complete | Last loss: 1.3850
# Episode 1590 complete | Last loss: 1.2529
# Episode 1600 complete | Last loss: 1.0074
# Episode 1610 complete | Last loss: 1.7511
# Episode 1620 complete | Last loss: 2.9908
# Episode 1630 complete | Last loss: 1.3785
# Episode 1640 complete | Last loss: 4.5126
# Episode 1650 complete | Last loss: 2.8313
# Episode 1660 complete | Last loss: 2.0482
# Episode 1670 complete | Last loss: 1.4850
# Episode 1680 complete | Last loss: 2.5798
# Episode 1690 complete | Last loss: 3.8862
# Episode 1700 complete | Last loss: 3.0721
# Episode 1710 complete | Last loss: 1.5656
# Episode 1720 complete | Last loss: 2.8523
# Episode 1730 complete | Last loss: 2.5355
# Episode 1740 complete | Last loss: 3.2769
# Episode 1750 complete | Last loss: 2.8700
# Episode 1760 complete | Last loss: 2.2521
# Episode 1770 complete | Last loss: 2.6329
# Episode 1780 complete | Last loss: 2.9334
# Episode 1790 complete | Last loss: 1.0370
# Episode 1800 complete | Last loss: 2.7434
# Episode 1810 complete | Last loss: 2.8524
# Episode 1820 complete | Last loss: 3.1620
# Episode 1830 complete | Last loss: 4.5702
# Episode 1840 complete | Last loss: 1.0792
# Episode 1850 complete | Last loss: 8.5644
# Episode 1860 complete | Last loss: 3.4128
# Episode 1870 complete | Last loss: 4.0878
# Episode 1880 complete | Last loss: 6.9615
# Episode 1890 complete | Last loss: 2.0670
# Episode 1900 complete | Last loss: 3.4820
# Episode 1910 complete | Last loss: 2.9815
# Episode 1920 complete | Last loss: 4.7174
# Episode 1930 complete | Last loss: 0.9875
# Episode 1940 complete | Last loss: 1.2824
# Episode 1950 complete | Last loss: 1.0399
# Episode 1960 complete | Last loss: 4.0594
# Episode 1970 complete | Last loss: 5.5010
# Episode 1980 complete | Last loss: 1.6447
# Episode 1990 complete | Last loss: 4.1432

# %%
env.add_model(model)

# %%
model = DQN(160,36)

# %%
import torch
import torch.nn as nn

class DQN(nn.Module):
    def __init__(self, history_dim, action_dim, hidden_dim=128):
        super(DQN, self).__init__()

        # New input dim is raw history + raw action
        combined_dim = history_dim + action_dim

        self.q_net = nn.Sequential(
            nn.Linear(combined_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)  # One Q-value per (history, action) pair
        )

    def forward(self, history_vec, actions_vecs):
        """
        Args:
            history_vec: Tensor (batch_size, history_dim)
            actions_vecs: Tensor (batch_size, num_actions, action_dim)

        Returns:
            q_values: Tensor (batch_size, num_actions)
        """
        batch_size, num_actions, action_dim = actions_vecs.shape
        history_dim = history_vec.shape[1]

        # Repeat history for each action
        history_repeated = history_vec.unsqueeze(1).repeat(1, num_actions, 1)  # (batch_size, num_actions, history_dim)

        # Concatenate raw history and actions
        concat = torch.cat([history_repeated, actions_vecs], dim=-1)  # (batch_size, num_actions, history_dim + action_dim)

        # Flatten for input to network
        concat_flat = concat.view(-1, history_dim + action_dim)  # (batch_size * num_actions, combined_dim)

        # print(concat_flat)
        # Pass through Q-network
        q_flat = self.q_net(concat_flat)  # (batch_size * num_actions, 1)
        q_values = q_flat.view(batch_size, num_actions)  # (batch_size, num_actions)

        return q_values

# %%
import torch
import torch.nn as nn

class DQN(nn.Module):
    def __init__(self, history_dim, action_dim, hidden_dim=128):
        super(DQN, self).__init__()

        self.history_encoder = nn.Sequential(
            nn.Linear(history_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )

        self.action_encoder = nn.Sequential(
            nn.Linear(action_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )

        self.scorer = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)  # Output one Q-value
        )

    def forward(self, history_vec, actions_vecs):
        """
        Args:
            history_vec: Tensor (batch_size, history_dim)
            actions_vecs: Tensor (batch_size, num_actions, action_dim)

        Returns:
            q_values: Tensor (batch_size, num_actions)
        """
        batch_size, num_actions, action_dim = actions_vecs.shape

        # Encode the history once
        history_encoded = self.history_encoder(history_vec)  # (batch_size, hidden_dim)
        # Flatten actions and encode them
        actions_flat = actions_vecs.view(-1, action_dim)  # (batch_size * num_actions, action_dim)
        actions_encoded = self.action_encoder(actions_flat)  # (batch_size * num_actions, hidden_dim)
        actions_encoded = actions_encoded.view(batch_size, num_actions, -1)  # (batch_size, num_actions, hidden_dim)

        # Repeat history for each action
        history_repeated = history_encoded.unsqueeze(1).repeat(1, num_actions, 1)  # (batch_size, num_actions, hidden_dim)

        # Concatenate encoded history and actions
        concat = torch.cat([history_repeated, actions_encoded], dim=-1)  # (batch_size, num_actions, hidden_dim*2)

        # Score each (history, action) pair
        q_values = self.scorer(concat).squeeze(-1)  # (batch_size, num_actions)

        return q_values

# %%
import torch
import torch.nn as nn

class DQN(nn.Module):
    def __init__(self, history_dim, action_dim, hidden_dim=128):
        super(DQN, self).__init__()

        self.history_encoder = nn.Sequential(
            nn.Linear(history_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01)
        )

        self.action_encoder = nn.Sequential(
            nn.Linear(action_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01)
        )

        self.scorer = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),
            nn.Linear(hidden_dim, 1)
        )

        # Apply custom initialization
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.kaiming_normal_(m.weight, nonlinearity='leaky_relu')
            nn.init.zeros_(m.bias)

    def forward(self, history_vec, actions_vecs):
        batch_size, num_actions, action_dim = actions_vecs.shape

        history_encoded = self.history_encoder(history_vec)  # (batch_size, hidden_dim)

        actions_flat = actions_vecs.view(-1, action_dim)
        actions_encoded = self.action_encoder(actions_flat)
        actions_encoded = actions_encoded.view(batch_size, num_actions, -1)

        history_repeated = history_encoded.unsqueeze(1).repeat(1, num_actions, 1)

        concat = torch.cat([history_repeated, actions_encoded], dim=-1)

        q_values = self.scorer(concat).squeeze(-1)  # (batch_size, num_actions)

        return q_values

# %%
class DQN(nn.Module):
    def __init__(self, history_dim, action_dim, hidden_dim=128):
        super(DQN, self).__init__()

        self.history_encoder = nn.Sequential(
            nn.Linear(history_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),  # <-- new layer
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01)
        )

        self.action_encoder = nn.Sequential(
            nn.Linear(action_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),  # <-- new layer
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01)
        )

        self.scorer = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),  # <-- new layer
            nn.Linear(hidden_dim, 1)
        )

        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.kaiming_normal_(m.weight, nonlinearity='leaky_relu')
            nn.init.zeros_(m.bias)

    def forward(self, history_vec, actions_vecs):
        batch_size, num_actions, action_dim = actions_vecs.shape

        history_encoded = self.history_encoder(history_vec)  # (batch_size, hidden_dim)

        actions_flat = actions_vecs.view(-1, action_dim)
        actions_encoded = self.action_encoder(actions_flat)
        actions_encoded = actions_encoded.view(batch_size, num_actions, -1)

        history_repeated = history_encoded.unsqueeze(1).repeat(1, num_actions, 1)

        concat = torch.cat([history_repeated, actions_encoded], dim=-1)

        q_values = self.scorer(concat).squeeze(-1)  # (batch_size, num_actions)

        return q_values

# %%
import torch
import torch.nn as nn

class DQN(nn.Module):
    def __init__(self, history_dim, action_dim, hidden_dim=128):
        super(DQN, self).__init__()

        self.history_encoder = nn.Sequential(
            nn.Linear(history_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01)
        )

        self.action_encoder = nn.Sequential(
            nn.Linear(action_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01)
        )

        self.scorer = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.LayerNorm(hidden_dim),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.01),
            nn.Linear(hidden_dim, 1)
        )

        # Apply custom initialization
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.kaiming_normal_(m.weight, nonlinearity='leaky_relu')
            nn.init.zeros_(m.bias)

    def forward(self, history_vec, actions_vecs):
        batch_size, num_actions, action_dim = actions_vecs.shape

        history_encoded = self.history_encoder(history_vec)  # (batch_size, hidden_dim)

        actions_flat = actions_vecs.view(-1, action_dim)
        actions_encoded = self.action_encoder(actions_flat)
        actions_encoded = actions_encoded.view(batch_size, num_actions, -1)

        history_repeated = history_encoded.unsqueeze(1).repeat(1, num_actions, 1)

        concat = torch.cat([history_repeated, actions_encoded], dim=-1)

        q_values = self.scorer(concat).squeeze(-1)  # (batch_size, num_actions)

        return q_values
